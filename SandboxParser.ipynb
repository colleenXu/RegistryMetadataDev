# %% [markdown]
# # Sandbox for working with parsers

# %% [markdown]
# ## Setup

# %%
## CX: allows multiple lines of code to print from one code block
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

## to get around bugs
import nest_asyncio
nest_asyncio.apply()

import pathlib
import pandas as pd
import re

from collections import defaultdict

# %% [markdown]
# ## DisGeNET disease->gene parsing

# %%
## put the path you want to use here
allgene_pmid_path = pathlib.Path.home().joinpath('Desktop', 'ScrippsJob', 'DisGeNET', 'all_gene_disease_pmid_associations.tsv.gz')

# %%
def process_gene(file_path_gene_disease):
    df_gene_disease = pd.read_csv(
        file_path_gene_disease,
        encoding="ISO-8859-1",
        sep="\t",
        comment="#",
        compression="gzip",
    )
    rename_gene = {
        "diseaseId": "umls",
        "geneId": "gene_id",
        "geneSymbol": "gene_name",
        "diseaseName": "disease_name",
        "pmid": "pubmed",
    }
    df_gene_disease = df_gene_disease.where((pd.notnull(df_gene_disease)), None)
    # source field could be multiple data sources concatenated by ";", break them into a list
    # df_gene_disease.source = to_list(df_gene_disease.source)
    # df_gene_disease.diseaseType = to_list(df_gene_disease.diseaseType)
    # df_gene_disease.diseaseSemanticType = to_list(df_gene_disease.diseaseSemanticType)
    d = defaultdict(list)
    # rename pandas columns
    df_gene_disease = df_gene_disease.rename(columns=rename_gene)
    # for each gene, group the results based on source, and merge all pubmed IDs together
    for grp, subdf in df_gene_disease.groupby(["umls", "source", "gene_id"]):
        records = subdf.to_dict(orient="records")
        doc = {"source": grp[1], "gene_id": int(grp[2]), "pubmed": set()}
        for record in records:
            for k, v in record.items():
                if isinstance(v, np.int64):
                    record[k] = int(v)
                if k in ["gene_name", "DSI", "DPI", "score", "EI"]:
                    doc[k] = v
                elif k in ["YearInitial", "YearFinal"]:
                    doc[k] = int(v) if v else v
                elif k == "pubmed" and v:
                    doc[k].add(int(v))
        doc["pubmed"] = list(doc["pubmed"])
        d[grp[0].replace("umls", "umls_cui")].append(doc)
    return d

# %%
processed1 = process_gene(allgene_pmid_path)

# %%
len(processed1['C0678222'])
# Out:
# 7473

# %% [markdown]
# ## HPO parsing

# %%
## put the path you want to use here
HPO_path = pathlib.Path.home().joinpath('Desktop', 'ScrippsJob', 'phenotype.hpoa')

# %%
def process_disease2hp(file_path_disease_hpo):
    df_disease_hpo = pd.read_csv(file_path_disease_hpo, sep="\t", skiprows=4, dtype=str)
    df_disease_hpo = df_disease_hpo.rename(
        index=str, columns={"DiseaseName": "disease_name", "#DatabaseID": "disease_id"}
    )
    
    ## removing qualifier = 'NOT' annotations, because it means the disease does not
    ##   have this phenotypic feature. The HPO website doesn't show these 'NOT' annots
    df_disease_hpo = df_disease_hpo[df_disease_hpo['Qualifier'] != "NOT"]
    ## then remove the qualifier
    df_disease_hpo.drop(columns = 'Qualifier', inplace = True)
    ## make sure all null values are None
    df_disease_hpo = df_disease_hpo.where((pd.notnull(df_disease_hpo)), None)
    
    d = []
    for did, subdf in df_disease_hpo.groupby("disease_id"):
        did = did.replace("ORPHA", "ORPHANET")
        records = subdf.to_dict(orient="records")
        
        pathway_related = []
        course = []
        modifiers = []
        inheritance = []
        
        for record in records:
            record_dict = {}
            if record["Aspect"] == "C":
                course.append(record["HPO_ID"])
                continue
            elif record["Aspect"] == "M":
                modifiers.append(record["HPO_ID"])
                continue
            elif record["Aspect"] == "I":
                inheritance.append(record["HPO_ID"])
                continue      
                
            for k, v in record.items():
                # name the field based on pathway database
                if (k == "Sex") and v:
                    record_dict['sex'] = v.lower()
                elif (k == 'Reference') and v: 
                ## only process if Reference has a value
                ## notes: OMIM:194190, OMIM:180849, OMIM:212050 are disease examples with > 1 type of reference
                    ## this is a string representing a list
                    tempRefs = v.split(";")
                    ## prepare to iterate through the tempRefs and store the processed data
                    tempProperties = {
                        'ISBN': [],
                        'PMID': [],
                        'http': [],
                        'DECIPHER': [],
                        'OMIM': [],
                        'ORPHA': []
                    }
                    
                    ## remove the prefixes or not? currently keeping the prefix
                    for i in tempRefs:
                        for key in tempProperties.keys():
                            if key in i:
                                ## replace curie prefix for isbn and orpha
                                if key == 'ISBN':
                                    tempProperties[key].append('ISBN:' + i.split(":")[1])
                                elif key == 'ORPHA':
                                    tempProperties[key].append('ORPHANET:' + i.split(":")[1])                                    
                                else:
                                    tempProperties[key].append(i)
                    ## ONLY add reference keys/values to the record if there are values
                    for k,v in tempProperties.items():
                        if v:
                            if k == 'ISBN':
                                record_dict['isbn_refs'] = v
                            elif k == 'PMID':
                                record_dict['pmid_refs'] = v                    
                            elif k == 'http':
                                record_dict['website_refs'] = v  
                            elif k == 'DECIPHER':
                                record_dict['decipher_refs'] = v  
                            elif k == 'OMIM':
                                record_dict['omim_refs'] = v  
                            elif k == 'ORPHA':
                                record_dict['orphanet_refs'] = v  
                elif (k == 'Frequency') and v:
                ## only process if Frequency has a value
                    tempDict = {}
                    if 'http' in v:  ## catching an error in the data
                        continue
                    elif 'HP:' in v:
                        tempDict['hp_freq'] = v
                    elif '%' in v:
                        tempFreq = float(v.strip('%')) / 100
                        ## only go forward if this is a valid fraction <=1
                        if tempFreq <= 1:
                            tempDict['numeric_freq'] = tempFreq
                    elif '/' in v:
                        ## idx 0 is numerator, idx 1 is denominator
                        tempL = [int(ele) for ele in v.split("/")]
                        ## only go forward if this is a valid fraction <=1
                        if (tempL[0] != 0) and (tempL[1] !=0) and (tempL[0] <= tempL[1]):
                            tempDict['freq_numerator'] = tempL[0]
                            tempDict['freq_denominator'] = tempL[1]
                            tempDict['numeric_freq'] = tempL[0] / tempL[1]

                    ## ONLY add frequency keys/values to the record if there are values
                    if tempDict:
                        record_dict.update(tempDict)
                        
                elif (k == 'Modifier') and v:
                ## only process if Modifier has a value
                    ## in <20 records, this is a delimited list with repeated values
                    ## this behavior matches the unlist behavior used with biothings APIs
                    ## https://github.com/kevinxin90/biothings.api/blob/master/biothings/utils/dataload.py
                    if ";" in v:
                        ## transform to list -> set->list to remove repeated values
                        tempMods = list(set(v.split(";")))
                        record_dict['modifier'] = tempMods
                    else:
                        record_dict['modifier'] = v
                elif k not in {"disease_id", "disease_name", 
                               "Aspect", "Sex", 
                               "Reference", "Frequency", 
                               "Modifier"}:
                    record_dict[k.lower()] = v
            pathway_related.append(record_dict)
        drecord = {
            "_id": did,
            "hpo": pathway_related,
            "disease_name": records[0]["disease_name"],
            "course": course,
            "modifiers": modifiers,
            "inheritance": inheritance
        }
        d.append(drecord)
 
    return {
        x["_id"]: [x["hpo"], x["disease_name"], x["course"], x["modifiers"], x["inheritance"]] for x in d
    }

# %%
processed1 = process_disease2hp(HPO_path)

# %%
## these are actually the same disease but obviously two diff sets of results. 
## see https://www.orpha.net/consor/cgi-bin/OC_Exp.php?lng=EN&Expert=1777 and its id mapping
## mydisease resolves these two as one entity as well
len(processed1['OMIM:218340'][0])
processed1['OMIM:218340'][1]
len(processed1['ORPHANET:1777'][0])
processed1['ORPHANET:1777'][1]
# Out:
# 30
# 'CRANIOFACIAL DYSMORPHISM WITH OCULAR COLOBOMA, ABSENT CORPUS CALLOSUM,AND AORTIC DILATATION'
# 25
# 'Temtamy syndrome'

# %%
# Out:
# 25
# [[{'hpo_id': 'HP:0000174',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000179',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000256',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000268',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000276',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000280',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000316',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000324',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000347',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000369',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000444',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000506',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000567',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000568',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0000612',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0001156',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0001249',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0001263',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0004942',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0001763',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0001831',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0002970',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040282',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0004209',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0005692',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040283',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'},
#   {'hpo_id': 'HP:0007370',
#    'orphanet_refs': ['ORPHANET:1777'],
#    'evidence': 'TAS',
#    'onset': None,
#    'hp_freq': 'HP:0040281',
#    'biocuration': 'ORPHA:orphadata[2021-02-08]'}],
#  'Temtamy syndrome',
#  [],
#  [],
#  []]

# %%
## CHECKS:
## decipher refs: 'DECIPHER:72', orphanet refs: ORPHANET:221 (none of these are in situations with multiple refs)
## omim and pmid refs in the same disease -> pheno association: 'OMIM:151610'
## combos of omim, isbn, website refs: 'OMIM:194190', OMIM:180849

processed1['OMIM:151610']
# Out:
# [[{'hpo_id': 'HP:0500043',
#    'pmid_refs': ['PMID:3767680'],
#    'omim_refs': ['OMIM:151610'],
#    'evidence': 'IEA',
#    'onset': None,
#    'freq_numerator': 20,
#    'freq_denominator': 20,
#    'numeric_freq': 1.0,
#    'biocuration': 'HPO:lccarmody[2018-10-05];HPO:skoehler[2018-10-08]'},
#   {'hpo_id': 'HP:0000492',
#    'pmid_refs': ['PMID:3767680'],
#    'evidence': 'IEA',
#    'onset': None,
#    'biocuration': 'HPO:lccarmody[2018-10-05]'},
#   {'hpo_id': 'HP:0000508',
#    'pmid_refs': ['PMID:3767680'],
#    'evidence': 'PCS',
#    'onset': None,
#    'biocuration': 'HPO:lccarmody[2018-10-05]'},
#   {'hpo_id': 'HP:0000478',
#    'omim_refs': ['OMIM:151610'],
#    'evidence': 'IEA',
#    'onset': None,
#    'biocuration': 'HPO:iea[2009-02-17]'}],
#  'LEVATOR-MEDIAL RECTUS SYNKINESIS',
#  [],
#  [],
#  ['HP:0000006']]

# %%
rawHPO = pd.read_csv(HPO_path, sep="\t", skiprows=4, dtype=str)

# %%
rawHPO[rawHPO['#DatabaseID'] == 'OMIM:191900']
# Out:
#        #DatabaseID            DiseaseName Qualifier      HPO_ID  \
# 41673  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0030953
# 41674  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0003565
# 41675  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0003621
# 41676  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0000365
# 41677  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0005764
# 41678  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0004322
# 41679  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0000083
# 41680  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0011107
# 41681  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0011227
# 41682  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0012432
# 41683  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0002829
# 41684  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0000408
# 41685  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0011463
# 41686  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0100759
# 41687  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0040186
# 41688  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0000509
# 41689  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0001917
# 41690  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0001954
# 41691  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0000006
# 41692  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0001974
# 41693  OMIM:191900  Muckle-Wells syndrome       NaN  HP:0003326
#
#                          Reference Evidence       Onset Frequency  Sex  \
# 41673                PMID:25766347      PCS         NaN       2/2  NaN
# 41674                PMID:25766347      TAS         NaN       2/2  NaN
# 41675                PMID:25766347      PCS         NaN       1/2  NaN
# 41676                PMID:14872505      PCS  HP:0011463       3/3  NaN
# 41677                PMID:25766347      PCS         NaN       2/2  NaN
# 41678                PMID:14872505      PCS         NaN       3/3  NaN
# 41679                 PMID:9704852      PCS  HP:0003584       NaN  NaN
# 41680                  OMIM:191900      TAS         NaN       NaN  NaN
# 41681                PMID:25766347      PCS         NaN       2/2  NaN
# 41682                PMID:14872505      PCS         NaN       3/3  NaN
# 41683                PMID:14872505      PCS         NaN       3/3  NaN
# 41684                PMID:25766347      PCS  HP:0011462       2/2  NaN
# 41685                PMID:25766347      PCS         NaN       NaN  NaN
# 41686                PMID:25766347      PCS         NaN       2/2  NaN
# 41687  PMID:25766347;PMID:14872505      PCS         NaN       5/5  NaN
# 41688                PMID:14872505      PCS         NaN       3/3  NaN
# 41689                 PMID:9704852      PCS  HP:0003584       NaN  NaN
# 41690  PMID:25766347;PMID:14872505      PCS         NaN       5/5  NaN
# 41691                PMID:11687797      PCS         NaN       NaN  NaN
# 41692                PMID:25766347      PCS         NaN       NaN  NaN
# 41693                  OMIM:191900      TAS         NaN       NaN  NaN
#
#                     Modifier Aspect  \
# 41673             HP:0025303      P
# 41674             HP:0025303      P
# 41675                    NaN      C
# 41676                    NaN      P
# 41677             HP:0025303      P
# 41678                    NaN      P
# 41679                    NaN      P
# 41680                    NaN      P
# 41681                    NaN      P
# 41682                    NaN      P
# 41683  HP:0025206;HP:0025303      P
# 41684                    NaN      P
# 41685                    NaN      C
# 41686                    NaN      P
# 41687             HP:0025303      P
# 41688  HP:0025206;HP:0025303      P
# 41689                    NaN      P
# 41690  HP:0025206;HP:0025303      P
# 41691                    NaN      I
# 41692                    NaN      P
# 41693             HP:0025303      P
#
#                                              Biocuration
# 41673                          HPO:probinson[2020-11-17]
# 41674  HPO:probinson[2009-02-17];HPO:probinson[2020-1...
# 41675                          HPO:probinson[2020-11-17]
# 41676  HPO:skoehler[2010-06-20];HPO:probinson[2020-11...
# 41677                          HPO:probinson[2020-11-17]
# 41678                          HPO:probinson[2020-11-17]
# 41679      HPO:iea[2009-02-17];HPO:probinson[2020-11-17]
# 41680                           HPO:skoehler[2012-10-17]
# 41681                          HPO:probinson[2020-11-17]
# 41682                          HPO:probinson[2020-11-17]
# 41683  HPO:probinson[2009-02-17];HPO:probinson[2020-1...
# 41684  HPO:probinson[2009-02-17];HPO:probinson[2020-1...
# 41685                          HPO:probinson[2020-11-17]
# 41686                          HPO:probinson[2020-11-17]
# 41687                          HPO:probinson[2020-11-17]
# 41688  HPO:probinson[2009-02-17];HPO:probinson[2020-1...
# 41689  HPO:probinson[2009-02-17];HPO:probinson[2020-1...
# 41690  HPO:probinson[2020-11-17];HPO:iea[2009-02-17];...
# 41691      HPO:iea[2009-02-17];HPO:probinson[2020-11-17]
# 41692  HPO:skoehler[2010-06-20];HPO:probinson[2020-11...
# 41693                          HPO:probinson[2009-02-17]

# %% [markdown]
# ## CTD troubleshooting

# %% [markdown]
# ### disease -> chemical

# %%
CTD_path1 = pathlib.Path.home().joinpath('Downloads', 'CTD_chemicals_diseases.csv.gz')

# %% [markdown]
# Changed to only keep the direct annotations, and for the chunking to work correctly (not override the entries) and to deal with typing issues for the columns

# %%
def process_chemical(file_path_chemical):
    chunksize = 100000
    d = []
    for chunk in pd.read_csv(file_path_chemical, chunksize=chunksize, sep=',', comment='#', compression='gzip', 
                             names=['chemical_name', 'mesh_chemical_id', 'cas_registry_number', 'DiseaseName', 'DiseaseID', 'direct_evidence', 'inference_gene_symbol', 'inference_score', 'omim_id', 'pubmed'],
                             dtype=str):
        temp_chunk = chunk.copy()
        temp_chunk = temp_chunk.where((pd.notnull(temp_chunk)), None)
        ## remove all inferred annotations
        temp_chunk = temp_chunk[~ temp_chunk['direct_evidence'].isna()]
        ## only work with records if the dataframe still has records 
        if not temp_chunk.empty: 
            ## make this the correct type
            temp_chunk['inference_score'] = temp_chunk['inference_score'].astype(float)
            temp_chunk = temp_chunk.where((pd.notnull(temp_chunk)), None)
            # add new column called source
            temp_chunk['source'] = 'CTD'         
            # the record in these fields are separated by '|', need to convert them into list
            for field_id in ['omim_id', 'pubmed']:
                temp_chunk[field_id] = temp_chunk[field_id].apply(lambda x: x.split('|') if x and '|' in x else x)
            for did, subdf in temp_chunk.groupby('DiseaseID'):
                records = subdf.to_dict(orient='records')
                chemical_related = [{k: v for k, v in record.items() if k not in {'DiseaseName', 'DiseaseID'}} for record in records]            
                drecord = {'_id': did, 'chemical': chemical_related}
                d.append(drecord)
    finalDict = {}
    ## For now, I'm not merging records. Current data situation is separate records when relationship is marker/mechanism AND therapeutic
    for ele in d:
        tempID = ele['_id']
        ## if an entry for this disease already exists in the dictionary
        if tempID in finalDict.keys():
            finalDict[tempID] = finalDict[tempID] + ele['chemical']
        else:
            finalDict[tempID] = ele['chemical']
    return finalDict

# %%
trial1 = process_chemical(CTD_path1)

# %%
trial1['MESH:D006974']
# Out:
# [{'chemical_name': 'Amitriptyline',
#   'mesh_chemical_id': 'D000639',
#   'cas_registry_number': '50-48-6',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '7123337',
#   'source': 'CTD'},
#  {'chemical_name': 'Angiotensin-Converting Enzyme Inhibitors',
#   'mesh_chemical_id': 'D000806',
#   'cas_registry_number': None,
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['17541236', '6168412'],
#   'source': 'CTD'},
#  {'chemical_name': 'Atenolol',
#   'mesh_chemical_id': 'D001262',
#   'cas_registry_number': '29122-68-7',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '2493837',
#   'source': 'CTD'},
#  {'chemical_name': 'Atrasentan',
#   'mesh_chemical_id': 'D000077868',
#   'cas_registry_number': None,
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '19326569',
#   'source': 'CTD'},
#  {'chemical_name': 'Bumetanide',
#   'mesh_chemical_id': 'D002034',
#   'cas_registry_number': '28395-03-1',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '6112544',
#   'source': 'CTD'},
#  {'chemical_name': 'Caffeine',
#   'mesh_chemical_id': 'D002110',
#   'cas_registry_number': '58-08-2',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '3020089',
#   'source': 'CTD'},
#  {'chemical_name': 'Chlorthalidone',
#   'mesh_chemical_id': 'D002752',
#   'cas_registry_number': '77-36-1',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '2493837',
#   'source': 'CTD'},
#  {'chemical_name': 'Cocaine',
#   'mesh_chemical_id': 'D003042',
#   'cas_registry_number': '50-36-2',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['18081441', '8969619'],
#   'source': 'CTD'},
#  {'chemical_name': 'Contraceptives, Oral',
#   'mesh_chemical_id': 'D003276',
#   'cas_registry_number': None,
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['1138738', '4559540', '5083217', '6809465', '7866596'],
#   'source': 'CTD'},
#  {'chemical_name': 'Contraceptives, Oral, Hormonal',
#   'mesh_chemical_id': 'D003278',
#   'cas_registry_number': None,
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '306034',
#   'source': 'CTD'},
#  {'chemical_name': 'Cyclopenthiazide',
#   'mesh_chemical_id': 'D003518',
#   'cas_registry_number': '742-20-1',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '1139266',
#   'source': 'CTD'},
#  {'chemical_name': 'Desoxycorticosterone',
#   'mesh_chemical_id': 'D003900',
#   'cas_registry_number': '64-85-7',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '1860718',
#   'source': 'CTD'},
#  {'chemical_name': 'Diazoxide',
#   'mesh_chemical_id': 'D003981',
#   'cas_registry_number': '364-98-7',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '4444609',
#   'source': 'CTD'},
#  {'chemical_name': 'Diuretics',
#   'mesh_chemical_id': 'D004232',
#   'cas_registry_number': None,
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['2493837', '6156352'],
#   'source': 'CTD'},
#  {'chemical_name': 'Enalapril',
#   'mesh_chemical_id': 'D004656',
#   'cas_registry_number': '75847-73-3',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['2493837', '3020089', '9546244'],
#   'source': 'CTD'},
#  {'chemical_name': 'Enzyme Inhibitors',
#   'mesh_chemical_id': 'D004791',
#   'cas_registry_number': None,
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '19326569',
#   'source': 'CTD'},
#  {'chemical_name': 'Ethinyl Estradiol',
#   'mesh_chemical_id': 'D004997',
#   'cas_registry_number': '57-63-6',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '1747706',
#   'source': 'CTD'},
#  {'chemical_name': 'Hydralazine',
#   'mesh_chemical_id': 'D006830',
#   'cas_registry_number': '86-54-4',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '6112544',
#   'source': 'CTD'},
#  {'chemical_name': 'Lisinopril',
#   'mesh_chemical_id': 'D017706',
#   'cas_registry_number': '83915-83-7',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '8723367',
#   'source': 'CTD'},
#  {'chemical_name': 'Losartan',
#   'mesh_chemical_id': 'D019808',
#   'cas_registry_number': '114798-26-4',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '19326569',
#   'source': 'CTD'},
#  {'chemical_name': 'Minoxidil',
#   'mesh_chemical_id': 'D008914',
#   'cas_registry_number': '38304-91-5',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['21786', '6156352'],
#   'source': 'CTD'},
#  {'chemical_name': 'Nifedipine',
#   'mesh_chemical_id': 'D009543',
#   'cas_registry_number': '21829-25-4',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': ['6861634', '8723367'],
#   'source': 'CTD'},
#  {'chemical_name': 'Nitrendipine',
#   'mesh_chemical_id': 'D009568',
#   'cas_registry_number': '39562-70-4',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '6085384',
#   'source': 'CTD'},
#  {'chemical_name': 'Norepinephrine',
#   'mesh_chemical_id': 'D009638',
#   'cas_registry_number': '51-41-2',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '6373596',
#   'source': 'CTD'},
#  {'chemical_name': 'Pindolol',
#   'mesh_chemical_id': 'D010869',
#   'cas_registry_number': '13523-86-9',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '1139266',
#   'source': 'CTD'},
#  {'chemical_name': 'Prednisolone',
#   'mesh_chemical_id': 'D011239',
#   'cas_registry_number': '50-24-8',
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '17541236',
#   'source': 'CTD'},
#  {'chemical_name': 'Propranolol',
#   'mesh_chemical_id': 'D011433',
#   'cas_registry_number': '525-66-6',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '6112544',
#   'source': 'CTD'},
#  {'chemical_name': 'Sodium Chloride, Dietary',
#   'mesh_chemical_id': 'D017673',
#   'cas_registry_number': None,
#   'direct_evidence': 'marker/mechanism',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '1860718',
#   'source': 'CTD'},
#  {'chemical_name': 'Spironolactone',
#   'mesh_chemical_id': 'D013148',
#   'cas_registry_number': '52-01-7',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '8723367',
#   'source': 'CTD'},
#  {'chemical_name': 'Sympatholytics',
#   'mesh_chemical_id': 'D013565',
#   'cas_registry_number': None,
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '6156352',
#   'source': 'CTD'},
#  {'chemical_name': 'trandolapril',
#   'mesh_chemical_id': 'C052035',
#   'cas_registry_number': None,
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '27428043',
#   'source': 'CTD'},
#  {'chemical_name': 'Trimethaphan',
#   'mesh_chemical_id': 'D014294',
#   'cas_registry_number': '7187-66-8',
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '727981',
#   'source': 'CTD'},
#  {'chemical_name': 'Valsartan',
#   'mesh_chemical_id': 'D000068756',
#   'cas_registry_number': None,
#   'direct_evidence': 'therapeutic',
#   'inference_gene_symbol': None,
#   'inference_score': None,
#   'omim_id': None,
#   'pubmed': '11560862',
#   'source': 'CTD'}]

# %% [markdown]
# ### disease -> pathway

# %%
CTD_path2 = pathlib.Path.home().joinpath('Downloads', 'CTD_diseases_pathways.csv.gz')

# %%
lookat = pd.read_csv(CTD_path2, sep=',', comment='#', compression='gzip', names=['DiseaseName', 'DiseaseID', 'pathway_name', 'pathway_id', 'inference_gene_symbol'])

# %%
lookat.dtypes
589408 == 572377 + 17031
# Out:
# DiseaseName              object
# DiseaseID                object
# pathway_name             object
# pathway_id               object
# inference_gene_symbol    object
# dtype: object
# True

# %%
lookat.DiseaseID.str.contains('OMIM:').value_counts()
lookat.DiseaseID.str.contains('MESH:').value_counts()
# Out:
# False    572377
# True      17031
# Name: DiseaseID, dtype: int64
# True     572377
# False     17031
# Name: DiseaseID, dtype: int64

# %%
lookat[lookat['DiseaseID'] == 'MESH:D011471']
# Out:
#                 DiseaseName     DiseaseID  \
# 493395  Prostatic Neoplasms  MESH:D011471
# 493396  Prostatic Neoplasms  MESH:D011471
# 493397  Prostatic Neoplasms  MESH:D011471
# 493398  Prostatic Neoplasms  MESH:D011471
# 493399  Prostatic Neoplasms  MESH:D011471
# ...                     ...           ...
# 504205  Prostatic Neoplasms  MESH:D011471
# 504206  Prostatic Neoplasms  MESH:D011471
# 504207  Prostatic Neoplasms  MESH:D011471
# 504208  Prostatic Neoplasms  MESH:D011471
# 504209  Prostatic Neoplasms  MESH:D011471
#
#                                              pathway_name  \
# 493395                    2-Oxocarboxylic acid metabolism
# 493396                   Abacavir transmembrane transport
# 493397                  Abacavir transport and metabolism
# 493398  Abasic sugar-phosphate removal via the single-...
# 493399             ABC-family proteins mediated transport
# ...                                                   ...
# 504205   YAP1- and WWTR1 (TAZ)-stimulated gene expression
# 504206   YAP1- and WWTR1 (TAZ)-stimulated gene expression
# 504207   YAP1- and WWTR1 (TAZ)-stimulated gene expression
# 504208    Zinc influx into cells by the SLC39 gene family
# 504209                                  Zinc transporters
#
#                  pathway_id inference_gene_symbol
# 493395        KEGG:hsa01210                  IDH1
# 493396  REACT:R-HSA-2161517               SLC22A3
# 493397  REACT:R-HSA-2161522               SLC22A3
# 493398    REACT:R-HSA-73930                 APEX1
# 493399   REACT:R-HSA-382556                 ABCC4
# ...                     ...                   ...
# 504205  REACT:R-HSA-2032785                 PPARA
# 504206  REACT:R-HSA-2032785                  RXRA
# 504207  REACT:R-HSA-2032785               TBL1XR1
# 504208   REACT:R-HSA-442380               SLC39A1
# 504209   REACT:R-HSA-435354               SLC39A1
#
# [10815 rows x 5 columns]

# %%
def process_pathway(file_path_pathway):
    # read in the data frame
    df_disease_pathway = pd.read_csv(file_path_pathway, sep=',', comment='#', compression='gzip',
                                     names=['DiseaseName', 'DiseaseID', 'pathway_name', 'pathway_id', 'inference_gene_symbol'],
                                     dtype=str)
    d = {}
    ## going to merge records with the same disease - pathway (but different inference_gene_symbol values)
    for grp, subdf in df_disease_pathway.groupby(['DiseaseID', 'pathway_id']):
        ## make a new record        
        record_dict = {
            'source': 'CTD',
            'pathway_name': subdf['pathway_name'].tolist()[0]}
        ## name the field based on pathway database
        tempPathwayID = grp[1].split(':')
        record_dict[tempPathwayID[0].lower() + '_pathway_id'] = tempPathwayID[1] 
        ## get the inference gene symbol list
        tempGeneL = subdf['inference_gene_symbol'].unique().tolist()
        if len(tempGeneL) == 1:
            record_dict['inference_gene_symbol'] = tempGeneL[0]
        else:
            record_dict['inference_gene_symbol'] = tempGeneL
        ## if disease key already exists in d
        if d.get(grp[0]):
            d[grp[0]].append(record_dict)
        else:
            d[grp[0]] = [record_dict]
        ## note: <20 diseases have >1000 unique pathways linked to them
    return d

# %%
pathwaydf = process_pathway(CTD_path2)

# %%
pathwaydf['MESH:D002294']
# Out:
# [{'source': 'CTD',
#   'pathway_name': 'Glycolysis / Gluconeogenesis',
#   'kegg_pathway_id': 'hsa00010',
#   'inference_gene_symbol': ['ENO1', 'GAPDH', 'PGAM1', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'Fructose and mannose metabolism',
#   'kegg_pathway_id': 'hsa00051',
#   'inference_gene_symbol': 'TPI1'},
#  {'source': 'CTD',
#   'pathway_name': 'Steroid hormone biosynthesis',
#   'kegg_pathway_id': 'hsa00140',
#   'inference_gene_symbol': ['CYP1A2', 'CYP1B1']},
#  {'source': 'CTD',
#   'pathway_name': 'Caffeine metabolism',
#   'kegg_pathway_id': 'hsa00232',
#   'inference_gene_symbol': 'CYP1A2'},
#  {'source': 'CTD',
#   'pathway_name': 'Pyrimidine metabolism',
#   'kegg_pathway_id': 'hsa00240',
#   'inference_gene_symbol': ['TYMS', 'UMPS']},
#  {'source': 'CTD',
#   'pathway_name': 'Glycine, serine and threonine metabolism',
#   'kegg_pathway_id': 'hsa00260',
#   'inference_gene_symbol': 'PGAM1'},
#  {'source': 'CTD',
#   'pathway_name': 'Tryptophan metabolism',
#   'kegg_pathway_id': 'hsa00380',
#   'inference_gene_symbol': ['CYP1A2', 'CYP1B1']},
#  {'source': 'CTD',
#   'pathway_name': 'Glutathione metabolism',
#   'kegg_pathway_id': 'hsa00480',
#   'inference_gene_symbol': ['GPX1', 'GSTM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Inositol phosphate metabolism',
#   'kegg_pathway_id': 'hsa00562',
#   'inference_gene_symbol': ['INPP5A', 'PIK3CA', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'Arachidonic acid metabolism',
#   'kegg_pathway_id': 'hsa00590',
#   'inference_gene_symbol': ['GPX1', 'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Linoleic acid metabolism',
#   'kegg_pathway_id': 'hsa00591',
#   'inference_gene_symbol': 'CYP1A2'},
#  {'source': 'CTD',
#   'pathway_name': 'One carbon pool by folate',
#   'kegg_pathway_id': 'hsa00670',
#   'inference_gene_symbol': 'TYMS'},
#  {'source': 'CTD',
#   'pathway_name': 'Retinol metabolism',
#   'kegg_pathway_id': 'hsa00830',
#   'inference_gene_symbol': 'CYP1A2'},
#  {'source': 'CTD',
#   'pathway_name': 'Metabolism of xenobiotics by cytochrome P450',
#   'kegg_pathway_id': 'hsa00980',
#   'inference_gene_symbol': ['CYP1A2', 'CYP1B1', 'GSTM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Drug metabolism - cytochrome P450',
#   'kegg_pathway_id': 'hsa00982',
#   'inference_gene_symbol': ['CYP1A2', 'GSTM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Drug metabolism - other enzymes',
#   'kegg_pathway_id': 'hsa00983',
#   'inference_gene_symbol': 'UMPS'},
#  {'source': 'CTD',
#   'pathway_name': 'Metabolic pathways',
#   'kegg_pathway_id': 'hsa01100',
#   'inference_gene_symbol': ['CYP1A2',
#    'ENO1',
#    'GAPDH',
#    'INPP5A',
#    'PGAM1',
#    'PTGS2',
#    'TPI1',
#    'TYMS',
#    'UMPS']},
#  {'source': 'CTD',
#   'pathway_name': 'Carbon metabolism',
#   'kegg_pathway_id': 'hsa01200',
#   'inference_gene_symbol': ['ENO1', 'GAPDH', 'PGAM1', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'Biosynthesis of amino acids',
#   'kegg_pathway_id': 'hsa01230',
#   'inference_gene_symbol': ['ENO1', 'GAPDH', 'PGAM1', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'EGFR tyrosine kinase inhibitor resistance',
#   'kegg_pathway_id': 'hsa01521',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'HGF',
#    'HRAS',
#    'IL6',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'STAT3',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Endocrine resistance',
#   'kegg_pathway_id': 'hsa01522',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDKN2A',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MMP9',
#    'NCOA3',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4',
#    'PIK3CA',
#    'PTK2',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Antifolate resistance',
#   'kegg_pathway_id': 'hsa01523',
#   'inference_gene_symbol': ['IL6', 'TYMS']},
#  {'source': 'CTD',
#   'pathway_name': 'Platinum drug resistance',
#   'kegg_pathway_id': 'hsa01524',
#   'inference_gene_symbol': ['AKT1',
#    'ATM',
#    'BIRC5',
#    'CDKN2A',
#    'GSTM1',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Ribosome biogenesis in eukaryotes',
#   'kegg_pathway_id': 'hsa03008',
#   'inference_gene_symbol': ['CSNK2A1', 'CSNK2A2', 'CSNK2B']},
#  {'source': 'CTD',
#   'pathway_name': 'Ribosome',
#   'kegg_pathway_id': 'hsa03010',
#   'inference_gene_symbol': 'MRPL13'},
#  {'source': 'CTD',
#   'pathway_name': 'RNA degradation',
#   'kegg_pathway_id': 'hsa03018',
#   'inference_gene_symbol': 'ENO1'},
#  {'source': 'CTD',
#   'pathway_name': 'Basal transcription factors',
#   'kegg_pathway_id': 'hsa03022',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'Spliceosome',
#   'kegg_pathway_id': 'hsa03040',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'Proteasome',
#   'kegg_pathway_id': 'hsa03050',
#   'inference_gene_symbol': 'SEM1'},
#  {'source': 'CTD',
#   'pathway_name': 'Nucleotide excision repair',
#   'kegg_pathway_id': 'hsa03420',
#   'inference_gene_symbol': ['ERCC2', 'XPC']},
#  {'source': 'CTD',
#   'pathway_name': 'Homologous recombination',
#   'kegg_pathway_id': 'hsa03440',
#   'inference_gene_symbol': ['ATM', 'RAD52', 'SEM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Non-homologous end-joining',
#   'kegg_pathway_id': 'hsa03450',
#   'inference_gene_symbol': 'PRKDC'},
#  {'source': 'CTD',
#   'pathway_name': 'MAPK signaling pathway',
#   'kegg_pathway_id': 'hsa04010',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HRAS',
#    'HSPA8',
#    'HSPB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'RASA1',
#    'TGFB1',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'ErbB signaling pathway',
#   'kegg_pathway_id': 'hsa04012',
#   'inference_gene_symbol': ['AKT1',
#    'AREG',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'PIK3CA',
#    'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'Ras signaling pathway',
#   'kegg_pathway_id': 'hsa04014',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTPN11',
#    'RASA1',
#    'TIAM1',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Rap1 signaling pathway',
#   'kegg_pathway_id': 'hsa04015',
#   'inference_gene_symbol': ['AKT1',
#    'CDH1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'TIAM1',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Calcium signaling pathway',
#   'kegg_pathway_id': 'hsa04020',
#   'inference_gene_symbol': ['EGFR', 'PTGER1', 'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'cGMP-PKG signaling pathway',
#   'kegg_pathway_id': 'hsa04022',
#   'inference_gene_symbol': ['AKT1', 'MAPK1', 'MAPK3', 'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'cAMP signaling pathway',
#   'kegg_pathway_id': 'hsa04024',
#   'inference_gene_symbol': ['AKT1',
#    'CREBBP',
#    'EP300',
#    'HCAR2',
#    'HCAR3',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TIAM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Cytokine-cytokine receptor interaction',
#   'kegg_pathway_id': 'hsa04060',
#   'inference_gene_symbol': ['CCL2',
#    'CXCL8',
#    'EGFR',
#    'HGF',
#    'IFNA2',
#    'IL6',
#    'MET',
#    'TGFB1',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Chemokine signaling pathway',
#   'kegg_pathway_id': 'hsa04062',
#   'inference_gene_symbol': ['AKT1',
#    'CCL2',
#    'CXCL8',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PTK2',
#    'STAT3',
#    'TIAM1']},
#  {'source': 'CTD',
#   'pathway_name': 'NF-kappa B signaling pathway',
#   'kegg_pathway_id': 'hsa04064',
#   'inference_gene_symbol': ['ATM',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'CXCL8',
#    'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'HIF-1 signaling pathway',
#   'kegg_pathway_id': 'hsa04066',
#   'inference_gene_symbol': ['AKT1',
#    'CREBBP',
#    'EGFR',
#    'ENO1',
#    'EP300',
#    'GAPDH',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STAT3',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'FoxO signaling pathway',
#   'kegg_pathway_id': 'hsa04068',
#   'inference_gene_symbol': ['AKT1',
#    'ATM',
#    'CCND1',
#    'CREBBP',
#    'EGFR',
#    'EP300',
#    'HRAS',
#    'IL6',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'SOD2',
#    'STAT3',
#    'STK11',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Phosphatidylinositol signaling system',
#   'kegg_pathway_id': 'hsa04070',
#   'inference_gene_symbol': ['INPP5A', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Sphingolipid signaling pathway',
#   'kegg_pathway_id': 'hsa04071',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Phospholipase D signaling pathway',
#   'kegg_pathway_id': 'hsa04072',
#   'inference_gene_symbol': ['AKT1',
#    'CXCL8',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PTPN11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Neuroactive ligand-receptor interaction',
#   'kegg_pathway_id': 'hsa04080',
#   'inference_gene_symbol': 'PTGER1'},
#  {'source': 'CTD',
#   'pathway_name': 'Cell cycle',
#   'kegg_pathway_id': 'hsa04110',
#   'inference_gene_symbol': ['ATM',
#    'CCND1',
#    'CDKN2A',
#    'CREBBP',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'MYC',
#    'PRKDC',
#    'SFN',
#    'TGFB1',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Oocyte meiosis',
#   'kegg_pathway_id': 'hsa04114',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'p53 signaling pathway',
#   'kegg_pathway_id': 'hsa04115',
#   'inference_gene_symbol': ['ATM', 'CCND1', 'CDKN2A', 'SFN', 'TP53', 'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Ubiquitin mediated proteolysis',
#   'kegg_pathway_id': 'hsa04120',
#   'inference_gene_symbol': ['UBA1', 'UBA7']},
#  {'source': 'CTD',
#   'pathway_name': 'Mitophagy - animal',
#   'kegg_pathway_id': 'hsa04137',
#   'inference_gene_symbol': ['CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'HRAS',
#    'KRAS',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Autophagy - animal',
#   'kegg_pathway_id': 'hsa04140',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Protein processing in endoplasmic reticulum',
#   'kegg_pathway_id': 'hsa04141',
#   'inference_gene_symbol': ['CRYAB', 'HSPA8', 'NFE2L2']},
#  {'source': 'CTD',
#   'pathway_name': 'Endocytosis',
#   'kegg_pathway_id': 'hsa04144',
#   'inference_gene_symbol': ['EGFR', 'HRAS', 'HSPA8', 'MET', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Phagosome',
#   'kegg_pathway_id': 'hsa04145',
#   'inference_gene_symbol': ['ITGA5', 'ITGB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Peroxisome',
#   'kegg_pathway_id': 'hsa04146',
#   'inference_gene_symbol': 'SOD2'},
#  {'source': 'CTD',
#   'pathway_name': 'mTOR signaling pathway',
#   'kegg_pathway_id': 'hsa04150',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'PI3K-Akt signaling pathway',
#   'kegg_pathway_id': 'hsa04151',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'IFNA2',
#    'IL6',
#    'ITGA5',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'MYC',
#    'PIK3CA',
#    'PTK2',
#    'STK11',
#    'TP53',
#    'TSC1',
#    'TSC2',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'AMPK signaling pathway',
#   'kegg_pathway_id': 'hsa04152',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'PIK3CA',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Apoptosis',
#   'kegg_pathway_id': 'hsa04210',
#   'inference_gene_symbol': ['AKT1',
#    'ATM',
#    'BIRC5',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Longevity regulating pathway',
#   'kegg_pathway_id': 'hsa04211',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'PIK3CA',
#    'SOD2',
#    'STK11',
#    'TP53',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Longevity regulating pathway - multiple species',
#   'kegg_pathway_id': 'hsa04213',
#   'inference_gene_symbol': ['AKT1',
#    'CRYAB',
#    'HDAC1',
#    'HDAC2',
#    'HRAS',
#    'HSPA8',
#    'KRAS',
#    'PIK3CA',
#    'SOD2']},
#  {'source': 'CTD',
#   'pathway_name': 'Apoptosis - multiple species',
#   'kegg_pathway_id': 'hsa04215',
#   'inference_gene_symbol': 'BIRC5'},
#  {'source': 'CTD',
#   'pathway_name': 'Ferroptosis',
#   'kegg_pathway_id': 'hsa04216',
#   'inference_gene_symbol': ['TP53', 'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Adrenergic signaling in cardiomyocytes',
#   'kegg_pathway_id': 'hsa04261',
#   'inference_gene_symbol': ['AKT1', 'MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Vascular smooth muscle contraction',
#   'kegg_pathway_id': 'hsa04270',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Wnt signaling pathway',
#   'kegg_pathway_id': 'hsa04310',
#   'inference_gene_symbol': ['CCND1',
#    'CREBBP',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'EP300',
#    'MYC',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Dorso-ventral axis formation',
#   'kegg_pathway_id': 'hsa04320',
#   'inference_gene_symbol': ['EGFR',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4']},
#  {'source': 'CTD',
#   'pathway_name': 'Notch signaling pathway',
#   'kegg_pathway_id': 'hsa04330',
#   'inference_gene_symbol': ['CREBBP',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4']},
#  {'source': 'CTD',
#   'pathway_name': 'Hedgehog signaling pathway',
#   'kegg_pathway_id': 'hsa04340',
#   'inference_gene_symbol': 'CCND1'},
#  {'source': 'CTD',
#   'pathway_name': 'TGF-beta signaling pathway',
#   'kegg_pathway_id': 'hsa04350',
#   'inference_gene_symbol': ['CREBBP',
#    'EP300',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Axon guidance',
#   'kegg_pathway_id': 'hsa04360',
#   'inference_gene_symbol': ['HRAS',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'PTPN11',
#    'RASA1']},
#  {'source': 'CTD',
#   'pathway_name': 'VEGF signaling pathway',
#   'kegg_pathway_id': 'hsa04370',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'HSPB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PTGS2',
#    'PTK2',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Apelin signaling pathway',
#   'kegg_pathway_id': 'hsa04371',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDH1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'NOTCH3']},
#  {'source': 'CTD',
#   'pathway_name': 'Osteoclast differentiation',
#   'kegg_pathway_id': 'hsa04380',
#   'inference_gene_symbol': ['AKT1', 'MAPK1', 'MAPK3', 'PIK3CA', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Hippo signaling pathway',
#   'kegg_pathway_id': 'hsa04390',
#   'inference_gene_symbol': ['AREG',
#    'BIRC5',
#    'CCND1',
#    'CDH1',
#    'MYC',
#    'SOX2',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Focal adhesion',
#   'kegg_pathway_id': 'hsa04510',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'EGFR',
#    'HGF',
#    'HRAS',
#    'ITGA5',
#    'ITGB1',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'ECM-receptor interaction',
#   'kegg_pathway_id': 'hsa04512',
#   'inference_gene_symbol': ['ITGA5', 'ITGB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Cell adhesion molecules (CAMs)',
#   'kegg_pathway_id': 'hsa04514',
#   'inference_gene_symbol': ['CDH1', 'ITGB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Adherens junction',
#   'kegg_pathway_id': 'hsa04520',
#   'inference_gene_symbol': ['CDH1',
#    'CREBBP',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'EGFR',
#    'EP300',
#    'FGFR1',
#    'MAPK1',
#    'MAPK3',
#    'MET']},
#  {'source': 'CTD',
#   'pathway_name': 'Tight junction',
#   'kegg_pathway_id': 'hsa04530',
#   'inference_gene_symbol': ['CCND1', 'CTTN', 'ITGB1', 'STK11', 'TIAM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Gap junction',
#   'kegg_pathway_id': 'hsa04540',
#   'inference_gene_symbol': ['EGFR', 'HRAS', 'KRAS', 'MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling pathways regulating pluripotency of stem cells',
#   'kegg_pathway_id': 'hsa04550',
#   'inference_gene_symbol': ['AKT1',
#    'FGFR1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'PIK3CA',
#    'SOX2',
#    'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Platelet activation',
#   'kegg_pathway_id': 'hsa04611',
#   'inference_gene_symbol': ['AKT1', 'ITGB1', 'MAPK1', 'MAPK3', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Antigen processing and presentation',
#   'kegg_pathway_id': 'hsa04612',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'Toll-like receptor signaling pathway',
#   'kegg_pathway_id': 'hsa04620',
#   'inference_gene_symbol': ['AKT1',
#    'CXCL8',
#    'IFNA2',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'NOD-like receptor signaling pathway',
#   'kegg_pathway_id': 'hsa04621',
#   'inference_gene_symbol': ['CARD18',
#    'CCL2',
#    'CXCL8',
#    'IFNA2',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'PYCARD',
#    'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'RIG-I-like receptor signaling pathway',
#   'kegg_pathway_id': 'hsa04622',
#   'inference_gene_symbol': ['CXCL8', 'IFNA2']},
#  {'source': 'CTD',
#   'pathway_name': 'Cytosolic DNA-sensing pathway',
#   'kegg_pathway_id': 'hsa04623',
#   'inference_gene_symbol': ['IFNA2', 'IL6', 'PYCARD']},
#  {'source': 'CTD',
#   'pathway_name': 'Jak-STAT signaling pathway',
#   'kegg_pathway_id': 'hsa04630',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CREBBP',
#    'EP300',
#    'HRAS',
#    'IFNA2',
#    'IL6',
#    'MYC',
#    'PIK3CA',
#    'PTPN11',
#    'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Hematopoietic cell lineage',
#   'kegg_pathway_id': 'hsa04640',
#   'inference_gene_symbol': ['IL6', 'ITGA5', 'MS4A1']},
#  {'source': 'CTD',
#   'pathway_name': 'Natural killer cell mediated cytotoxicity',
#   'kegg_pathway_id': 'hsa04650',
#   'inference_gene_symbol': ['HRAS',
#    'IFNA2',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'IL-17 signaling pathway',
#   'kegg_pathway_id': 'hsa04657',
#   'inference_gene_symbol': ['CCL2',
#    'CXCL8',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'MMP9',
#    'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Th1 and Th2 cell differentiation',
#   'kegg_pathway_id': 'hsa04658',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3', 'NOTCH1', 'NOTCH2', 'NOTCH3']},
#  {'source': 'CTD',
#   'pathway_name': 'Th17 cell differentiation',
#   'kegg_pathway_id': 'hsa04659',
#   'inference_gene_symbol': ['IL6', 'MAPK1', 'MAPK3', 'STAT3', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'T cell receptor signaling pathway',
#   'kegg_pathway_id': 'hsa04660',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'B cell receptor signaling pathway',
#   'kegg_pathway_id': 'hsa04662',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Fc epsilon RI signaling pathway',
#   'kegg_pathway_id': 'hsa04664',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Fc gamma R-mediated phagocytosis',
#   'kegg_pathway_id': 'hsa04666',
#   'inference_gene_symbol': ['AKT1', 'MAPK1', 'MAPK3', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'TNF signaling pathway',
#   'kegg_pathway_id': 'hsa04668',
#   'inference_gene_symbol': ['AKT1',
#    'CCL2',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'MMP9',
#    'PIK3CA',
#    'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Leukocyte transendothelial migration',
#   'kegg_pathway_id': 'hsa04670',
#   'inference_gene_symbol': ['ITGB1', 'MMP9', 'PIK3CA', 'PTK2', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Intestinal immune network for IgA production',
#   'kegg_pathway_id': 'hsa04672',
#   'inference_gene_symbol': ['IL6', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Circadian entrainment',
#   'kegg_pathway_id': 'hsa04713',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Long-term potentiation',
#   'kegg_pathway_id': 'hsa04720',
#   'inference_gene_symbol': ['CREBBP',
#    'EP300',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Neurotrophin signaling pathway',
#   'kegg_pathway_id': 'hsa04722',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PTPN11',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Retrograde endocannabinoid signaling',
#   'kegg_pathway_id': 'hsa04723',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3', 'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Glutamatergic synapse',
#   'kegg_pathway_id': 'hsa04724',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Cholinergic synapse',
#   'kegg_pathway_id': 'hsa04725',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Serotonergic synapse',
#   'kegg_pathway_id': 'hsa04726',
#   'inference_gene_symbol': ['HRAS', 'KRAS', 'MAPK1', 'MAPK3', 'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Dopaminergic synapse',
#   'kegg_pathway_id': 'hsa04728',
#   'inference_gene_symbol': 'AKT1'},
#  {'source': 'CTD',
#   'pathway_name': 'Long-term depression',
#   'kegg_pathway_id': 'hsa04730',
#   'inference_gene_symbol': ['HRAS', 'KRAS', 'MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Inflammatory mediator regulation of TRP channels',
#   'kegg_pathway_id': 'hsa04750',
#   'inference_gene_symbol': 'PIK3CA'},
#  {'source': 'CTD',
#   'pathway_name': 'Regulation of actin cytoskeleton',
#   'kegg_pathway_id': 'hsa04810',
#   'inference_gene_symbol': ['EGFR',
#    'FGFR1',
#    'HRAS',
#    'ITGA5',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PTK2',
#    'TIAM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Insulin signaling pathway',
#   'kegg_pathway_id': 'hsa04910',
#   'inference_gene_symbol': ['AKT1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'GnRH signaling pathway',
#   'kegg_pathway_id': 'hsa04912',
#   'inference_gene_symbol': ['EGFR', 'HRAS', 'KRAS', 'MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Ovarian steroidogenesis',
#   'kegg_pathway_id': 'hsa04913',
#   'inference_gene_symbol': ['CYP1B1', 'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Progesterone-mediated oocyte maturation',
#   'kegg_pathway_id': 'hsa04914',
#   'inference_gene_symbol': ['AKT1', 'KRAS', 'MAPK1', 'MAPK3', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Estrogen signaling pathway',
#   'kegg_pathway_id': 'hsa04915',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'HRAS',
#    'HSPA8',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MMP9',
#    'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Melanogenesis',
#   'kegg_pathway_id': 'hsa04916',
#   'inference_gene_symbol': ['CREBBP',
#    'EP300',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Prolactin signaling pathway',
#   'kegg_pathway_id': 'hsa04917',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Thyroid hormone synthesis',
#   'kegg_pathway_id': 'hsa04918',
#   'inference_gene_symbol': 'GPX1'},
#  {'source': 'CTD',
#   'pathway_name': 'Thyroid hormone signaling pathway',
#   'kegg_pathway_id': 'hsa04919',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CREBBP',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'NCOA3',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4',
#    'PIK3CA',
#    'TP53',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Adipocytokine signaling pathway',
#   'kegg_pathway_id': 'hsa04920',
#   'inference_gene_symbol': ['AKT1', 'PTPN11', 'STAT3', 'STK11']},
#  {'source': 'CTD',
#   'pathway_name': 'Oxytocin signaling pathway',
#   'kegg_pathway_id': 'hsa04921',
#   'inference_gene_symbol': ['CCND1',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Glucagon signaling pathway',
#   'kegg_pathway_id': 'hsa04922',
#   'inference_gene_symbol': ['AKT1', 'CREBBP', 'EP300', 'PGAM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Regulation of lipolysis in adipocytes',
#   'kegg_pathway_id': 'hsa04923',
#   'inference_gene_symbol': ['AKT1', 'PIK3CA', 'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Type II diabetes mellitus',
#   'kegg_pathway_id': 'hsa04930',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Insulin resistance',
#   'kegg_pathway_id': 'hsa04931',
#   'inference_gene_symbol': ['AKT1', 'IL6', 'PIK3CA', 'PTPN11', 'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Non-alcoholic fatty liver disease (NAFLD)',
#   'kegg_pathway_id': 'hsa04932',
#   'inference_gene_symbol': ['AKT1',
#    'CEBPA',
#    'CXCL8',
#    'IL6',
#    'PIK3CA',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'AGE-RAGE signaling pathway in diabetic complications',
#   'kegg_pathway_id': 'hsa04933',
#   'inference_gene_symbol': ['AKT1',
#    'CCL2',
#    'CCND1',
#    'CXCL8',
#    'HRAS',
#    'IL6',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STAT3',
#    'TGFB1',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Aldosterone-regulated sodium reabsorption',
#   'kegg_pathway_id': 'hsa04960',
#   'inference_gene_symbol': ['KRAS', 'MAPK1', 'MAPK3', 'PIK3CA', 'SFN']},
#  {'source': 'CTD',
#   'pathway_name': 'Vasopressin-regulated water reabsorption',
#   'kegg_pathway_id': 'hsa04962',
#   'inference_gene_symbol': 'AQP3'},
#  {'source': 'CTD',
#   'pathway_name': 'Carbohydrate digestion and absorption',
#   'kegg_pathway_id': 'hsa04973',
#   'inference_gene_symbol': ['AKT1', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Mineral absorption',
#   'kegg_pathway_id': 'hsa04978',
#   'inference_gene_symbol': 'MT1A'},
#  {'source': 'CTD',
#   'pathway_name': "Alzheimer's disease",
#   'kegg_pathway_id': 'hsa05010',
#   'inference_gene_symbol': ['GAPDH', 'MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': "Parkinson's disease",
#   'kegg_pathway_id': 'hsa05012',
#   'inference_gene_symbol': ['UBA1', 'UBA7', 'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Amyotrophic lateral sclerosis (ALS)',
#   'kegg_pathway_id': 'hsa05014',
#   'inference_gene_symbol': ['GPX1', 'TP53']},
#  {'source': 'CTD',
#   'pathway_name': "Huntington's disease",
#   'kegg_pathway_id': 'hsa05016',
#   'inference_gene_symbol': ['CREBBP',
#    'EP300',
#    'GPX1',
#    'HDAC1',
#    'HDAC2',
#    'SOD2',
#    'TP53',
#    'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Prion diseases',
#   'kegg_pathway_id': 'hsa05020',
#   'inference_gene_symbol': ['IL6', 'MAPK1', 'MAPK3', 'NOTCH1']},
#  {'source': 'CTD',
#   'pathway_name': 'Amphetamine addiction',
#   'kegg_pathway_id': 'hsa05031',
#   'inference_gene_symbol': 'HDAC1'},
#  {'source': 'CTD',
#   'pathway_name': 'Alcoholism',
#   'kegg_pathway_id': 'hsa05034',
#   'inference_gene_symbol': ['HDAC1',
#    'HDAC2',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Bacterial invasion of epithelial cells',
#   'kegg_pathway_id': 'hsa05100',
#   'inference_gene_symbol': ['CDH1',
#    'CTTN',
#    'ITGA5',
#    'ITGB1',
#    'MET',
#    'PIK3CA',
#    'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'Epithelial cell signaling in Helicobacter pylori infection',
#   'kegg_pathway_id': 'hsa05120',
#   'inference_gene_symbol': ['CXCL8', 'EGFR', 'MET', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Pathogenic Escherichia coli infection',
#   'kegg_pathway_id': 'hsa05130',
#   'inference_gene_symbol': ['CDH1', 'CTTN', 'ITGB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Shigellosis',
#   'kegg_pathway_id': 'hsa05131',
#   'inference_gene_symbol': ['CTTN',
#    'CXCL8',
#    'ITGA5',
#    'ITGB1',
#    'MAPK1',
#    'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Salmonella infection',
#   'kegg_pathway_id': 'hsa05132',
#   'inference_gene_symbol': ['CXCL8', 'IL6', 'MAPK1', 'MAPK3', 'PYCARD']},
#  {'source': 'CTD',
#   'pathway_name': 'Pertussis',
#   'kegg_pathway_id': 'hsa05133',
#   'inference_gene_symbol': ['CXCL8',
#    'IL6',
#    'ITGA5',
#    'ITGB1',
#    'MAPK1',
#    'MAPK3',
#    'PYCARD']},
#  {'source': 'CTD',
#   'pathway_name': 'Legionellosis',
#   'kegg_pathway_id': 'hsa05134',
#   'inference_gene_symbol': ['CXCL8', 'HSPA8', 'IL6', 'PYCARD']},
#  {'source': 'CTD',
#   'pathway_name': 'Leishmaniasis',
#   'kegg_pathway_id': 'hsa05140',
#   'inference_gene_symbol': ['ITGB1', 'MAPK1', 'MAPK3', 'PTGS2', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Chagas disease (American trypanosomiasis)',
#   'kegg_pathway_id': 'hsa05142',
#   'inference_gene_symbol': ['AKT1',
#    'CCL2',
#    'CXCL8',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'African trypanosomiasis',
#   'kegg_pathway_id': 'hsa05143',
#   'inference_gene_symbol': 'IL6'},
#  {'source': 'CTD',
#   'pathway_name': 'Malaria',
#   'kegg_pathway_id': 'hsa05144',
#   'inference_gene_symbol': ['CCL2', 'CXCL8', 'HGF', 'IL6', 'MET', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Toxoplasmosis',
#   'kegg_pathway_id': 'hsa05145',
#   'inference_gene_symbol': ['AKT1',
#    'HSPA8',
#    'ITGB1',
#    'MAPK1',
#    'MAPK3',
#    'STAT3',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Amoebiasis',
#   'kegg_pathway_id': 'hsa05146',
#   'inference_gene_symbol': ['CXCL8',
#    'HSPB1',
#    'IL6',
#    'PIK3CA',
#    'PTK2',
#    'SERPINB3',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Staphylococcus aureus infection',
#   'kegg_pathway_id': 'hsa05150',
#   'inference_gene_symbol': 'KRT10'},
#  {'source': 'CTD',
#   'pathway_name': 'Tuberculosis',
#   'kegg_pathway_id': 'hsa05152',
#   'inference_gene_symbol': ['AKT1',
#    'CREBBP',
#    'EP300',
#    'IFNA2',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Hepatitis C',
#   'kegg_pathway_id': 'hsa05160',
#   'inference_gene_symbol': ['AKT1',
#    'CXCL8',
#    'EGFR',
#    'HRAS',
#    'IFNA2',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STAT3',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Hepatitis B',
#   'kegg_pathway_id': 'hsa05161',
#   'inference_gene_symbol': ['AKT1',
#    'BIRC5',
#    'CCND1',
#    'CREBBP',
#    'CXCL8',
#    'EP300',
#    'HRAS',
#    'IFNA2',
#    'IL6',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MMP9',
#    'MYC',
#    'PIK3CA',
#    'STAT3',
#    'TGFB1',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Measles',
#   'kegg_pathway_id': 'hsa05162',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'HSPA8',
#    'IFNA2',
#    'IL6',
#    'PIK3CA',
#    'RACK1',
#    'STAT3',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Influenza A',
#   'kegg_pathway_id': 'hsa05164',
#   'inference_gene_symbol': ['AKT1',
#    'CCL2',
#    'CREBBP',
#    'CXCL8',
#    'EP300',
#    'HSPA8',
#    'IFNA2',
#    'IL6',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PYCARD']},
#  {'source': 'CTD',
#   'pathway_name': 'HTLV-I infection',
#   'kegg_pathway_id': 'hsa05166',
#   'inference_gene_symbol': ['AKT1',
#    'ATM',
#    'CCND1',
#    'CDKN2A',
#    'CREBBP',
#    'EP300',
#    'HRAS',
#    'IL6',
#    'KRAS',
#    'MYC',
#    'PIK3CA',
#    'TGFB1',
#    'TP53',
#    'VDAC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Herpes simplex infection',
#   'kegg_pathway_id': 'hsa05168',
#   'inference_gene_symbol': ['CCL2',
#    'CREBBP',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'EP300',
#    'IFNA2',
#    'IL6',
#    'PTPN11',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Epstein-Barr virus infection',
#   'kegg_pathway_id': 'hsa05169',
#   'inference_gene_symbol': ['AKT1',
#    'CREBBP',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'HSPA8',
#    'HSPB1',
#    'MYC',
#    'PIK3CA',
#    'SEM1',
#    'STAT3',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Pathways in cancer',
#   'kegg_pathway_id': 'hsa05200',
#   'inference_gene_symbol': ['AKT1',
#    'BIRC5',
#    'CCND1',
#    'CDH1',
#    'CDKN2A',
#    'CEBPA',
#    'CREBBP',
#    'CXCL8',
#    'EGFR',
#    'EP300',
#    'FGFR1',
#    'HDAC1',
#    'HDAC2',
#    'HGF',
#    'HRAS',
#    'IL6',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'MMP9',
#    'MYC',
#    'PIK3CA',
#    'PTGER1',
#    'PTGS2',
#    'PTK2',
#    'RARB',
#    'STAT3',
#    'TGFB1',
#    'TP53',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Transcriptional misregulation in cancer',
#   'kegg_pathway_id': 'hsa05202',
#   'inference_gene_symbol': ['ATM',
#    'CEBPA',
#    'CXCL8',
#    'HDAC1',
#    'HDAC2',
#    'IL6',
#    'MET',
#    'MMP9',
#    'MYC',
#    'PTK2',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Viral carcinogenesis',
#   'kegg_pathway_id': 'hsa05203',
#   'inference_gene_symbol': ['CCND1',
#    'CDKN2A',
#    'CREBBP',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STAT3',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Chemical carcinogenesis',
#   'kegg_pathway_id': 'hsa05204',
#   'inference_gene_symbol': ['CYP1A2', 'CYP1B1', 'GSTM1', 'PTGS2']},
#  {'source': 'CTD',
#   'pathway_name': 'Proteoglycans in cancer',
#   'kegg_pathway_id': 'hsa05205',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CTTN',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'ITGA5',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'MMP9',
#    'MYC',
#    'PIK3CA',
#    'PTK2',
#    'PTPN11',
#    'STAT3',
#    'TGFB1',
#    'TIAM1',
#    'TP53',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'MicroRNAs in cancer',
#   'kegg_pathway_id': 'hsa05206',
#   'inference_gene_symbol': ['ATM',
#    'CCND1',
#    'CDKN2A',
#    'CREBBP',
#    'CYP1B1',
#    'EGFR',
#    'EP300',
#    'HDAC1',
#    'HRAS',
#    'ITGA5',
#    'KRAS',
#    'MAPK1',
#    'MET',
#    'MIR205',
#    'MMP9',
#    'MYC',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4',
#    'PIK3CA',
#    'PTGS2',
#    'STAT3',
#    'TP53',
#    'TP63',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Colorectal cancer',
#   'kegg_pathway_id': 'hsa05210',
#   'inference_gene_symbol': ['AKT1',
#    'BIRC5',
#    'CCND1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'PIK3CA',
#    'TGFB1',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Renal cell carcinoma',
#   'kegg_pathway_id': 'hsa05211',
#   'inference_gene_symbol': ['AKT1',
#    'CREBBP',
#    'EP300',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTPN11',
#    'TGFB1',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Pancreatic cancer',
#   'kegg_pathway_id': 'hsa05212',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDKN2A',
#    'EGFR',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'STAT3',
#    'TGFB1',
#    'TP53',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Endometrial cancer',
#   'kegg_pathway_id': 'hsa05213',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDH1',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Glioma',
#   'kegg_pathway_id': 'hsa05214',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDKN2A',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Prostate cancer',
#   'kegg_pathway_id': 'hsa05215',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CREBBP',
#    'EGFR',
#    'EP300',
#    'FGFR1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Thyroid cancer',
#   'kegg_pathway_id': 'hsa05216',
#   'inference_gene_symbol': ['CCND1',
#    'CDH1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Basal cell carcinoma',
#   'kegg_pathway_id': 'hsa05217',
#   'inference_gene_symbol': 'TP53'},
#  {'source': 'CTD',
#   'pathway_name': 'Melanoma',
#   'kegg_pathway_id': 'hsa05218',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDH1',
#    'CDKN2A',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Bladder cancer',
#   'kegg_pathway_id': 'hsa05219',
#   'inference_gene_symbol': ['CCND1',
#    'CDH1',
#    'CDKN2A',
#    'CXCL8',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MMP9',
#    'MYC',
#    'TP53',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Chronic myeloid leukemia',
#   'kegg_pathway_id': 'hsa05220',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDKN2A',
#    'HDAC1',
#    'HDAC2',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'PIK3CA',
#    'PTPN11',
#    'TGFB1',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Acute myeloid leukemia',
#   'kegg_pathway_id': 'hsa05221',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CEBPA',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'PIK3CA',
#    'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Small cell lung cancer',
#   'kegg_pathway_id': 'hsa05222',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'ITGB1',
#    'MYC',
#    'PIK3CA',
#    'PTGS2',
#    'PTK2',
#    'RARB',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Non-small cell lung cancer',
#   'kegg_pathway_id': 'hsa05223',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'CDKN2A',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'RARB',
#    'STAT3',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Breast cancer',
#   'kegg_pathway_id': 'hsa05224',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'EGFR',
#    'FGFR1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MYC',
#    'NCOA3',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4',
#    'PIK3CA',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Central carbon metabolism in cancer',
#   'kegg_pathway_id': 'hsa05230',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'MYC',
#    'PGAM1',
#    'PIK3CA',
#    'SIRT3',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Choline metabolism in cancer',
#   'kegg_pathway_id': 'hsa05231',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Autoimmune thyroid disease',
#   'kegg_pathway_id': 'hsa05320',
#   'inference_gene_symbol': 'IFNA2'},
#  {'source': 'CTD',
#   'pathway_name': 'Inflammatory bowel disease (IBD)',
#   'kegg_pathway_id': 'hsa05321',
#   'inference_gene_symbol': ['IL6', 'STAT3', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Rheumatoid arthritis',
#   'kegg_pathway_id': 'hsa05323',
#   'inference_gene_symbol': ['CCL2', 'CXCL8', 'IL6', 'TGFB1', 'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Graft-versus-host disease',
#   'kegg_pathway_id': 'hsa05332',
#   'inference_gene_symbol': 'IL6'},
#  {'source': 'CTD',
#   'pathway_name': 'Hypertrophic cardiomyopathy (HCM)',
#   'kegg_pathway_id': 'hsa05410',
#   'inference_gene_symbol': ['IL6', 'ITGA5', 'ITGB1', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Arrhythmogenic right ventricular cardiomyopathy (ARVC)',
#   'kegg_pathway_id': 'hsa05412',
#   'inference_gene_symbol': ['ITGA5', 'ITGB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Dilated cardiomyopathy',
#   'kegg_pathway_id': 'hsa05414',
#   'inference_gene_symbol': ['ITGA5', 'ITGB1', 'TGFB1']},
#  {'source': 'CTD',
#   'pathway_name': 'Viral myocarditis',
#   'kegg_pathway_id': 'hsa05416',
#   'inference_gene_symbol': 'CCND1'},
#  {'source': 'CTD',
#   'pathway_name': 'Fluid shear stress and atherosclerosis',
#   'kegg_pathway_id': 'hsa05418',
#   'inference_gene_symbol': ['AKT1',
#    'CCL2',
#    'GSTM1',
#    'MMP9',
#    'NFE2L2',
#    'PIK3CA',
#    'PTK2',
#    'TP53',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Glycolysis (Embden-Meyerhof pathway), glucose => pyruvate',
#   'kegg_pathway_id': 'hsa_M00001',
#   'inference_gene_symbol': ['ENO1', 'GAPDH', 'PGAM1', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'Glycolysis, core module involving three-carbon compounds',
#   'kegg_pathway_id': 'hsa_M00002',
#   'inference_gene_symbol': ['ENO1', 'GAPDH', 'PGAM1', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'Gluconeogenesis, oxaloacetate => fructose-6P',
#   'kegg_pathway_id': 'hsa_M00003',
#   'inference_gene_symbol': ['ENO1', 'GAPDH', 'PGAM1', 'TPI1']},
#  {'source': 'CTD',
#   'pathway_name': 'Uridine monophosphate biosynthesis, glutamine (+ PRPP) => UMP',
#   'kegg_pathway_id': 'hsa_M00051',
#   'inference_gene_symbol': 'UMPS'},
#  {'source': 'CTD',
#   'pathway_name': 'Inositol phosphate metabolism, Ins(1,3,4,5)P4 => Ins(1,3,4)P3 => myo-inositol',
#   'kegg_pathway_id': 'hsa_M00131',
#   'inference_gene_symbol': 'INPP5A'},
#  {'source': 'CTD',
#   'pathway_name': 'Holo-TFIIH complex',
#   'kegg_pathway_id': 'hsa_M00290',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'BRCA1-associated genome surveillance complex (BASC)',
#   'kegg_pathway_id': 'hsa_M00295',
#   'inference_gene_symbol': 'ATM'},
#  {'source': 'CTD',
#   'pathway_name': 'DNA-PK complex',
#   'kegg_pathway_id': 'hsa_M00297',
#   'inference_gene_symbol': 'PRKDC'},
#  {'source': 'CTD',
#   'pathway_name': 'Proteasome, 19S regulatory particle (PA700)',
#   'kegg_pathway_id': 'hsa_M00341',
#   'inference_gene_symbol': 'SEM1'},
#  {'source': 'CTD',
#   'pathway_name': 'Spliceosome, Prp19/CDC5L complex',
#   'kegg_pathway_id': 'hsa_M00353',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'Spliceosome, 35S U5-snRNP',
#   'kegg_pathway_id': 'hsa_M00355',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'PI3K-Akt signaling',
#   'kegg_pathway_id': 'hsa_M00676',
#   'inference_gene_symbol': ['AKT1', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'TGF-beta signaling',
#   'kegg_pathway_id': 'hsa_M00680',
#   'inference_gene_symbol': 'TGFB1'},
#  {'source': 'CTD',
#   'pathway_name': 'Notch signaling',
#   'kegg_pathway_id': 'hsa_M00682',
#   'inference_gene_symbol': ['NOTCH1', 'NOTCH2', 'NOTCH3', 'NOTCH4']},
#  {'source': 'CTD',
#   'pathway_name': 'JAK-STAT signaling',
#   'kegg_pathway_id': 'hsa_M00684',
#   'inference_gene_symbol': 'STAT3'},
#  {'source': 'CTD',
#   'pathway_name': 'MAPK (ERK1/2) signaling',
#   'kegg_pathway_id': 'hsa_M00687',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'DNA damage-induced cell cycle checkpoints',
#   'kegg_pathway_id': 'hsa_M00691',
#   'inference_gene_symbol': 'ATM'},
#  {'source': 'CTD',
#   'pathway_name': 'Cell cycle - G1/S transition',
#   'kegg_pathway_id': 'hsa_M00692',
#   'inference_gene_symbol': 'CCND1'},
#  {'source': 'CTD',
#   'pathway_name': 'Interleukin-6 signaling',
#   'react_pathway_id': 'R-HSA-1059683',
#   'inference_gene_symbol': ['IL6', 'PTPN11', 'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Apoptosis',
#   'react_pathway_id': 'R-HSA-109581',
#   'inference_gene_symbol': ['AKT1',
#    'CDH1',
#    'PTK2',
#    'SEM1',
#    'SFN',
#    'TP53',
#    'TP63']},
#  {'source': 'CTD',
#   'pathway_name': 'Hemostasis',
#   'react_pathway_id': 'R-HSA-109582',
#   'inference_gene_symbol': ['AKT1',
#    'ANXA2',
#    'ANXA5',
#    'CREBBP',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'HGF',
#    'HRAS',
#    'IFNA2',
#    'ITGA5',
#    'ITGB1',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PPIA',
#    'PTK2',
#    'PTPN11',
#    'TGFB1',
#    'TP53',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Intrinsic Pathway for Apoptosis',
#   'react_pathway_id': 'R-HSA-109606',
#   'inference_gene_symbol': ['AKT1', 'SFN', 'TP53', 'TP63']},
#  {'source': 'CTD',
#   'pathway_name': 'PKB-mediated events',
#   'react_pathway_id': 'R-HSA-109703',
#   'inference_gene_symbol': ['AKT1', 'STK11', 'TSC1', 'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'PI3K Cascade',
#   'react_pathway_id': 'R-HSA-109704',
#   'inference_gene_symbol': ['AKT1',
#    'FGFR1',
#    'PIK3CA',
#    'PTPN11',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'MAPK3 (ERK1) activation',
#   'react_pathway_id': 'R-HSA-110056',
#   'inference_gene_symbol': ['IL6', 'MAPK3', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Translesion synthesis by Y family DNA polymerases bypasses lesions on DNA template',
#   'react_pathway_id': 'R-HSA-110313',
#   'inference_gene_symbol': 'UBA7'},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of BAD and translocation to mitochondria',
#   'react_pathway_id': 'R-HSA-111447',
#   'inference_gene_symbol': ['AKT1', 'SFN']},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of NOXA and translocation to mitochondria',
#   'react_pathway_id': 'R-HSA-111448',
#   'inference_gene_symbol': 'TP53'},
#  {'source': 'CTD',
#   'pathway_name': 'Apoptotic cleavage of cellular proteins',
#   'react_pathway_id': 'R-HSA-111465',
#   'inference_gene_symbol': ['CDH1', 'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'Opioid Signalling',
#   'react_pathway_id': 'R-HSA-111885',
#   'inference_gene_symbol': 'MAPK1'},
#  {'source': 'CTD',
#   'pathway_name': 'phospho-PLA2 pathway',
#   'react_pathway_id': 'R-HSA-111995',
#   'inference_gene_symbol': 'MAPK1'},
#  {'source': 'CTD',
#   'pathway_name': 'Ca-dependent events',
#   'react_pathway_id': 'R-HSA-111996',
#   'inference_gene_symbol': 'MAPK1'},
#  {'source': 'CTD',
#   'pathway_name': 'G-protein mediated events',
#   'react_pathway_id': 'R-HSA-112040',
#   'inference_gene_symbol': 'MAPK1'},
#  {'source': 'CTD',
#   'pathway_name': 'PLC beta mediated events',
#   'react_pathway_id': 'R-HSA-112043',
#   'inference_gene_symbol': 'MAPK1'},
#  {'source': 'CTD',
#   'pathway_name': 'Neurotransmitter Release Cycle',
#   'react_pathway_id': 'R-HSA-112310',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'Neurotransmitter Receptor Binding And Downstream Transmission In The  Postsynaptic Cell',
#   'react_pathway_id': 'R-HSA-112314',
#   'inference_gene_symbol': ['HRAS', 'MAPK1']},
#  {'source': 'CTD',
#   'pathway_name': 'Transmission across Chemical Synapses',
#   'react_pathway_id': 'R-HSA-112315',
#   'inference_gene_symbol': ['HRAS', 'HSPA8', 'MAPK1']},
#  {'source': 'CTD',
#   'pathway_name': 'Neuronal System',
#   'react_pathway_id': 'R-HSA-112316',
#   'inference_gene_symbol': ['HRAS', 'HSPA8', 'MAPK1']},
#  {'source': 'CTD',
#   'pathway_name': 'Formation of RNA Pol II elongation complex',
#   'react_pathway_id': 'R-HSA-112382',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'IRS-mediated signalling',
#   'react_pathway_id': 'R-HSA-112399',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'PTPN11',
#    'RASA1',
#    'SEM1',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'RAF-independent MAPK1/3 activation',
#   'react_pathway_id': 'R-HSA-112409',
#   'inference_gene_symbol': ['IL6', 'MAPK1', 'MAPK3', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'MAPK1 (ERK2) activation',
#   'react_pathway_id': 'R-HSA-112411',
#   'inference_gene_symbol': ['IL6', 'MAPK1', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'SOS-mediated signalling',
#   'react_pathway_id': 'R-HSA-112412',
#   'inference_gene_symbol': ['EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PTK2',
#    'RASA1',
#    'SEM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Formation of the Early Elongation Complex',
#   'react_pathway_id': 'R-HSA-113418',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'E2F mediated regulation of DNA replication',
#   'react_pathway_id': 'R-HSA-113510',
#   'inference_gene_symbol': 'TYMS'},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of BH3-only proteins',
#   'react_pathway_id': 'R-HSA-114452',
#   'inference_gene_symbol': ['AKT1', 'SFN', 'TP53', 'TP63']},
#  {'source': 'CTD',
#   'pathway_name': 'GPVI-mediated activation cascade',
#   'react_pathway_id': 'R-HSA-114604',
#   'inference_gene_symbol': ['AKT1', 'PIK3CA', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Platelet degranulation',
#   'react_pathway_id': 'R-HSA-114608',
#   'inference_gene_symbol': ['ANXA5', 'HGF', 'PPIA', 'TGFB1', 'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Downstream signaling events of B Cell Receptor (BCR)',
#   'react_pathway_id': 'R-HSA-1168372',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTPN11',
#    'SEM1',
#    'TP53',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of NF-kappaB in B cells',
#   'react_pathway_id': 'R-HSA-1169091',
#   'inference_gene_symbol': 'SEM1'},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of RAS in B cells',
#   'react_pathway_id': 'R-HSA-1169092',
#   'inference_gene_symbol': ['HRAS', 'KRAS']},
#  {'source': 'CTD',
#   'pathway_name': 'ISG15 antiviral mechanism',
# ...
#   'inference_gene_symbol': ['ATM',
#    'EP300',
#    'ERCC2',
#    'PRKDC',
#    'RAD52',
#    'TP53',
#    'UBA7',
#    'XPC']},
#  {'source': 'CTD',
#   'pathway_name': 'Gene Expression',
#   'react_pathway_id': 'R-HSA-74160',
#   'inference_gene_symbol': ['AKT1',
#    'APOBEC3B',
#    'ATM',
#    'BIRC5',
#    'CDKN2A',
#    'CREBBP',
#    'CSNK2A1',
#    'CSNK2A2',
#    'CSNK2B',
#    'EGFR',
#    'EP300',
#    'ERCC2',
#    'HDAC1',
#    'HDAC2',
#    'HSPA8',
#    'HSPB1',
#    'MAPK3',
#    'MYC',
#    'NOTCH1',
#    'NOTCH2',
#    'NOTCH3',
#    'NOTCH4',
#    'RARB',
#    'SEM1',
#    'SFN',
#    'STK11',
#    'TP53',
#    'TP63',
#    'TSC1',
#    'TSC2',
#    'VEGFA',
#    'WWOX']},
#  {'source': 'CTD',
#   'pathway_name': 'Purine catabolism',
#   'react_pathway_id': 'R-HSA-74259',
#   'inference_gene_symbol': 'GPX1'},
#  {'source': 'CTD',
#   'pathway_name': 'Signal attenuation',
#   'react_pathway_id': 'R-HSA-74749',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Insulin receptor signalling cascade',
#   'react_pathway_id': 'R-HSA-74751',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'PTPN11',
#    'RASA1',
#    'SEM1',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling by Insulin receptor',
#   'react_pathway_id': 'R-HSA-74752',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'PTPN11',
#    'RASA1',
#    'SEM1',
#    'STK11',
#    'TSC1',
#    'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Chk1/Chk2(Cds1) mediated inactivation of Cyclin B:Cdk1 complex',
#   'react_pathway_id': 'R-HSA-75035',
#   'inference_gene_symbol': 'SFN'},
#  {'source': 'CTD',
#   'pathway_name': 'mRNA Editing',
#   'react_pathway_id': 'R-HSA-75072',
#   'inference_gene_symbol': 'APOBEC3B'},
#  {'source': 'CTD',
#   'pathway_name': 'Formation of the Editosome',
#   'react_pathway_id': 'R-HSA-75094',
#   'inference_gene_symbol': 'APOBEC3B'},
#  {'source': 'CTD',
#   'pathway_name': 'Apoptotic execution  phase',
#   'react_pathway_id': 'R-HSA-75153',
#   'inference_gene_symbol': ['CDH1', 'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'Dissolution of Fibrin Clot',
#   'react_pathway_id': 'R-HSA-75205',
#   'inference_gene_symbol': 'ANXA2'},
#  {'source': 'CTD',
#   'pathway_name': 'Ubiquitin-dependent degradation of Cyclin D',
#   'react_pathway_id': 'R-HSA-75815',
#   'inference_gene_symbol': ['CCND1', 'SEM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Platelet Adhesion to exposed collagen',
#   'react_pathway_id': 'R-HSA-75892',
#   'inference_gene_symbol': 'ITGB1'},
#  {'source': 'CTD',
#   'pathway_name': 'TNF signaling',
#   'react_pathway_id': 'R-HSA-75893',
#   'inference_gene_symbol': 'RACK1'},
#  {'source': 'CTD',
#   'pathway_name': 'RNA Polymerase II Transcription Initiation',
#   'react_pathway_id': 'R-HSA-75953',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'RNA Polymerase II Transcription Elongation',
#   'react_pathway_id': 'R-HSA-75955',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'Platelet activation, signaling and aggregation',
#   'react_pathway_id': 'R-HSA-76002',
#   'inference_gene_symbol': ['AKT1',
#    'ANXA5',
#    'HGF',
#    'MAPK1',
#    'MAPK3',
#    'PIK3CA',
#    'PPIA',
#    'PTK2',
#    'PTPN11',
#    'TGFB1',
#    'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Response to elevated platelet cytosolic Ca2+',
#   'react_pathway_id': 'R-HSA-76005',
#   'inference_gene_symbol': ['ANXA5', 'HGF', 'PPIA', 'TGFB1', 'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'Platelet Aggregation (Plug Formation)',
#   'react_pathway_id': 'R-HSA-76009',
#   'inference_gene_symbol': ['AKT1', 'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'RNA Polymerase II Transcription Initiation And Promoter Clearance',
#   'react_pathway_id': 'R-HSA-76042',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'RNA Pol II CTD phosphorylation and interaction with CE',
#   'react_pathway_id': 'R-HSA-77075',
#   'inference_gene_symbol': 'ERCC2'},
#  {'source': 'CTD',
#   'pathway_name': 'The NLRP3 inflammasome',
#   'react_pathway_id': 'R-HSA-844456',
#   'inference_gene_symbol': 'PYCARD'},
#  {'source': 'CTD',
#   'pathway_name': 'The AIM2 inflammasome',
#   'react_pathway_id': 'R-HSA-844615',
#   'inference_gene_symbol': 'PYCARD'},
#  {'source': 'CTD',
#   'pathway_name': 'Interferon gamma signaling',
#   'react_pathway_id': 'R-HSA-877300',
#   'inference_gene_symbol': 'PTPN11'},
#  {'source': 'CTD',
#   'pathway_name': 'Regulation of IFNG signaling',
#   'react_pathway_id': 'R-HSA-877312',
#   'inference_gene_symbol': 'PTPN11'},
#  {'source': 'CTD',
#   'pathway_name': 'Advanced glycosylation endproduct receptor signaling',
#   'react_pathway_id': 'R-HSA-879415',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Gastrin-CREB signalling pathway via PKC and MAPK',
#   'react_pathway_id': 'R-HSA-881907',
#   'inference_gene_symbol': ['ANXA1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTGER1',
#    'PTK2',
#    'RASA1',
#    'SEM1']},
#  {'source': 'CTD',
#   'pathway_name': 'ERBB2 Activates PTK6 Signaling',
#   'react_pathway_id': 'R-HSA-8847993',
#   'inference_gene_symbol': 'EGFR'},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling by PTK6',
#   'react_pathway_id': 'R-HSA-8848021',
#   'inference_gene_symbol': ['AKT1',
#    'CCND1',
#    'EGFR',
#    'HRAS',
#    'KRAS',
#    'RASA1',
#    'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'PTK6 Regulates RTKs and Their Effectors AKT1 and DOK1',
#   'react_pathway_id': 'R-HSA-8849469',
#   'inference_gene_symbol': 'AKT1'},
#  {'source': 'CTD',
#   'pathway_name': 'PTK6 Regulates Cell Cycle',
#   'react_pathway_id': 'R-HSA-8849470',
#   'inference_gene_symbol': 'CCND1'},
#  {'source': 'CTD',
#   'pathway_name': 'PTK6 Regulates RHO GTPases, RAS GTPase and MAP kinases',
#   'react_pathway_id': 'R-HSA-8849471',
#   'inference_gene_symbol': ['HRAS', 'KRAS', 'RASA1']},
#  {'source': 'CTD',
#   'pathway_name': 'PTK6 Activates STAT3',
#   'react_pathway_id': 'R-HSA-8849474',
#   'inference_gene_symbol': 'STAT3'},
#  {'source': 'CTD',
#   'pathway_name': 'MET activates RAS signaling',
#   'react_pathway_id': 'R-HSA-8851805',
#   'inference_gene_symbol': ['HGF', 'HRAS', 'KRAS', 'MET']},
#  {'source': 'CTD',
#   'pathway_name': 'MET activates PI3K/AKT signaling',
#   'react_pathway_id': 'R-HSA-8851907',
#   'inference_gene_symbol': ['HGF', 'MET', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Protein ubiquitination',
#   'react_pathway_id': 'R-HSA-8852135',
#   'inference_gene_symbol': ['PRKDC', 'UBA1']},
#  {'source': 'CTD',
#   'pathway_name': 'The role of GTSE1 in G2/M progression after G2 checkpoint',
#   'react_pathway_id': 'R-HSA-8852276',
#   'inference_gene_symbol': ['SEM1', 'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling by FGFR3 fusions in cancer',
#   'react_pathway_id': 'R-HSA-8853334',
#   'inference_gene_symbol': ['HRAS', 'KRAS', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling by plasma membrane FGFR1 fusions',
#   'react_pathway_id': 'R-HSA-8853336',
#   'inference_gene_symbol': 'FGFR1'},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling by FGFR3 point mutants in cancer',
#   'react_pathway_id': 'R-HSA-8853338',
#   'inference_gene_symbol': ['HRAS', 'KRAS', 'PIK3CA']},
#  {'source': 'CTD',
#   'pathway_name': 'RET signaling',
#   'react_pathway_id': 'R-HSA-8853659',
#   'inference_gene_symbol': ['EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'PTPN11',
#    'RASA1',
#    'SEM1']},
#  {'source': 'CTD',
#   'pathway_name': 'FBXL7 down-regulates AURKA during mitotic entry and in early mitosis',
#   'react_pathway_id': 'R-HSA-8854050',
#   'inference_gene_symbol': 'SEM1'},
#  {'source': 'CTD',
#   'pathway_name': 'TBC/RABGAPs',
#   'react_pathway_id': 'R-HSA-8854214',
#   'inference_gene_symbol': ['TSC1', 'TSC2']},
#  {'source': 'CTD',
#   'pathway_name': 'Cargo recognition for clathrin-mediated endocytosis',
#   'react_pathway_id': 'R-HSA-8856825',
#   'inference_gene_symbol': 'EGFR'},
#  {'source': 'CTD',
#   'pathway_name': 'Clathrin-mediated endocytosis',
#   'react_pathway_id': 'R-HSA-8856828',
#   'inference_gene_symbol': ['CTTN', 'EGFR', 'HSPA8']},
#  {'source': 'CTD',
#   'pathway_name': 'PTK6 promotes HIF1A stabilization',
#   'react_pathway_id': 'R-HSA-8857538',
#   'inference_gene_symbol': 'EGFR'},
#  {'source': 'CTD',
#   'pathway_name': "Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models",
#   'react_pathway_id': 'R-HSA-8862803',
#   'inference_gene_symbol': 'SOD2'},
#  {'source': 'CTD',
#   'pathway_name': 'Neurodegenerative Diseases',
#   'react_pathway_id': 'R-HSA-8863678',
#   'inference_gene_symbol': 'SOD2'},
#  {'source': 'CTD',
#   'pathway_name': 'Downregulation of ERBB2 signaling',
#   'react_pathway_id': 'R-HSA-8863795',
#   'inference_gene_symbol': ['AKT1', 'EGFR']},
#  {'source': 'CTD',
#   'pathway_name': 'Transcriptional regulation by the AP-2 (TFAP2) family of transcription factors',
#   'react_pathway_id': 'R-HSA-8864260',
#   'inference_gene_symbol': ['CREBBP',
#    'EGFR',
#    'EP300',
#    'MYC',
#    'VEGFA',
#    'WWOX']},
#  {'source': 'CTD',
#   'pathway_name': 'MET activates PTPN11',
#   'react_pathway_id': 'R-HSA-8865999',
#   'inference_gene_symbol': ['HGF', 'MET', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Synthesis of active ubiquitin: roles of E1 and E2 enzymes',
#   'react_pathway_id': 'R-HSA-8866652',
#   'inference_gene_symbol': 'UBA1'},
#  {'source': 'CTD',
#   'pathway_name': 'E3 ubiquitin ligases ubiquitinate target proteins',
#   'react_pathway_id': 'R-HSA-8866654',
#   'inference_gene_symbol': 'PRKDC'},
#  {'source': 'CTD',
#   'pathway_name': 'Negative regulation of activity of TFAP2 (AP-2) family transcription factors',
#   'react_pathway_id': 'R-HSA-8866904',
#   'inference_gene_symbol': 'WWOX'},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of the TFAP2 (AP-2) family of transcription factors',
#   'react_pathway_id': 'R-HSA-8866907',
#   'inference_gene_symbol': ['CREBBP', 'EP300', 'WWOX']},
#  {'source': 'CTD',
#   'pathway_name': 'TFAP2 (AP-2) family regulates transcription of growth factors and their receptors',
#   'react_pathway_id': 'R-HSA-8866910',
#   'inference_gene_symbol': ['EGFR', 'VEGFA']},
#  {'source': 'CTD',
#   'pathway_name': 'TFAP2 (AP-2) family regulates transcription of cell cycle factors',
#   'react_pathway_id': 'R-HSA-8866911',
#   'inference_gene_symbol': 'MYC'},
#  {'source': 'CTD',
#   'pathway_name': 'MET activates PTK2 signaling',
#   'react_pathway_id': 'R-HSA-8874081',
#   'inference_gene_symbol': ['HGF', 'ITGB1', 'MET', 'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'InlB-mediated entry of Listeria monocytogenes into host cell',
#   'react_pathway_id': 'R-HSA-8875360',
#   'inference_gene_symbol': 'MET'},
#  {'source': 'CTD',
#   'pathway_name': 'MET interacts with TNS proteins',
#   'react_pathway_id': 'R-HSA-8875513',
#   'inference_gene_symbol': ['HGF', 'ITGB1', 'MET']},
#  {'source': 'CTD',
#   'pathway_name': 'MET activates RAP1 and RAC1',
#   'react_pathway_id': 'R-HSA-8875555',
#   'inference_gene_symbol': ['HGF', 'MET']},
#  {'source': 'CTD',
#   'pathway_name': 'MET receptor recycling',
#   'react_pathway_id': 'R-HSA-8875656',
#   'inference_gene_symbol': ['HGF', 'MET']},
#  {'source': 'CTD',
#   'pathway_name': 'MET activates STAT3',
#   'react_pathway_id': 'R-HSA-8875791',
#   'inference_gene_symbol': ['HGF', 'MET', 'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'MET promotes cell motility',
#   'react_pathway_id': 'R-HSA-8875878',
#   'inference_gene_symbol': ['HGF', 'ITGB1', 'MET', 'PTK2']},
#  {'source': 'CTD',
#   'pathway_name': 'RAB GEFs exchange GTP for GDP on RABs',
#   'react_pathway_id': 'R-HSA-8876198',
#   'inference_gene_symbol': 'AKT1'},
#  {'source': 'CTD',
#   'pathway_name': 'Listeria monocytogenes entry into host cells',
#   'react_pathway_id': 'R-HSA-8876384',
#   'inference_gene_symbol': ['CDH1', 'MET']},
#  {'source': 'CTD',
#   'pathway_name': 'InlA-mediated entry of Listeria monocytogenes into host cells',
#   'react_pathway_id': 'R-HSA-8876493',
#   'inference_gene_symbol': 'CDH1'},
#  {'source': 'CTD',
#   'pathway_name': 'Protein methylation',
#   'react_pathway_id': 'R-HSA-8876725',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'GABA synthesis, release, reuptake and degradation',
#   'react_pathway_id': 'R-HSA-888590',
#   'inference_gene_symbol': 'HSPA8'},
#  {'source': 'CTD',
#   'pathway_name': 'Interferon alpha/beta signaling',
#   'react_pathway_id': 'R-HSA-909733',
#   'inference_gene_symbol': ['IFNA2', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Meiotic recombination',
#   'react_pathway_id': 'R-HSA-912446',
#   'inference_gene_symbol': 'ATM'},
#  {'source': 'CTD',
#   'pathway_name': 'Interleukin receptor SHC signaling',
#   'react_pathway_id': 'R-HSA-912526',
#   'inference_gene_symbol': ['EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTK2',
#    'RASA1',
#    'SEM1']},
#  {'source': 'CTD',
#   'pathway_name': 'Regulation of signaling by CBL',
#   'react_pathway_id': 'R-HSA-912631',
#   'inference_gene_symbol': 'PIK3CA'},
#  {'source': 'CTD',
#   'pathway_name': 'Regulation of IFNA signaling',
#   'react_pathway_id': 'R-HSA-912694',
#   'inference_gene_symbol': ['IFNA2', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Interferon Signaling',
#   'react_pathway_id': 'R-HSA-913531',
#   'inference_gene_symbol': ['IFNA2', 'MAPK3', 'PTPN11', 'UBA7']},
#  {'source': 'CTD',
#   'pathway_name': 'TRAF3-dependent IRF activation pathway',
#   'react_pathway_id': 'R-HSA-918233',
#   'inference_gene_symbol': ['CREBBP', 'EP300']},
#  {'source': 'CTD',
#   'pathway_name': 'TRAF6 mediated IRF7 activation',
#   'react_pathway_id': 'R-HSA-933541',
#   'inference_gene_symbol': ['CREBBP', 'EP300', 'IFNA2']},
#  {'source': 'CTD',
#   'pathway_name': 'Negative regulators of RIG-I/MDA5 signaling',
#   'react_pathway_id': 'R-HSA-936440',
#   'inference_gene_symbol': 'UBA7'},
#  {'source': 'CTD',
#   'pathway_name': 'Activation of IRF3/IRF7 mediated by TBK1/IKK epsilon',
#   'react_pathway_id': 'R-HSA-936964',
#   'inference_gene_symbol': 'PTPN11'},
#  {'source': 'CTD',
#   'pathway_name': 'TRIF-mediated TLR3/TLR4 signaling',
#   'react_pathway_id': 'R-HSA-937061',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3', 'PTPN11']},
#  {'source': 'CTD',
#   'pathway_name': 'Transport to the Golgi and subsequent modification',
#   'react_pathway_id': 'R-HSA-948021',
#   'inference_gene_symbol': 'AREG'},
#  {'source': 'CTD',
#   'pathway_name': 'TRAF6 mediated induction of NFkB and MAP kinases upon TLR7/8 or 9 activation',
#   'react_pathway_id': 'R-HSA-975138',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'MyD88 dependent cascade initiated on endosome',
#   'react_pathway_id': 'R-HSA-975155',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'MyD88 cascade initiated on plasma membrane',
#   'react_pathway_id': 'R-HSA-975871',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3']},
#  {'source': 'CTD',
#   'pathway_name': 'Growth hormone receptor signaling',
#   'react_pathway_id': 'R-HSA-982772',
#   'inference_gene_symbol': ['MAPK1', 'MAPK3', 'STAT3']},
#  {'source': 'CTD',
#   'pathway_name': 'Antigen processing: Ubiquitination & Proteasome degradation',
#   'react_pathway_id': 'R-HSA-983168',
#   'inference_gene_symbol': ['SEM1', 'UBA1', 'UBA7']},
#  {'source': 'CTD',
#   'pathway_name': 'Class I MHC mediated antigen processing & presentation',
#   'react_pathway_id': 'R-HSA-983169',
#   'inference_gene_symbol': ['SEM1', 'UBA1', 'UBA7']},
#  {'source': 'CTD',
#   'pathway_name': 'Factors involved in megakaryocyte development and platelet production',
#   'react_pathway_id': 'R-HSA-983231',
#   'inference_gene_symbol': ['CREBBP',
#    'EP300',
#    'HDAC1',
#    'HDAC2',
#    'IFNA2',
#    'TP53']},
#  {'source': 'CTD',
#   'pathway_name': 'Signaling by the B Cell Receptor (BCR)',
#   'react_pathway_id': 'R-HSA-983705',
#   'inference_gene_symbol': ['AKT1',
#    'EGFR',
#    'FGFR1',
#    'HGF',
#    'HRAS',
#    'KRAS',
#    'MAPK1',
#    'MAPK3',
#    'MET',
#    'PIK3CA',
#    'PTPN11',
#    'SEM1',
#    'TP53',
#    'TSC2']}]
