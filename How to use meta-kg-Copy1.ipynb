# %% [markdown]
# # Install and import biothings_explorer

# %%
# !pip install git+https://github.com/biothings/biothings_explorer.git

# %%
from biothings_explorer.smartapi_kg import MetaKG

# %% [markdown]
# # Construct Meta-KG from SmartAPI

# %%
kg = MetaKG()

# %%
kg.constructMetaKG(source="remote")

# %%
kg.filter({})
# Out:
# [{'inputs': [{'id': 'GO', 'semantic': 'MolecularActivity'}],
#   'outputs': [{'id': 'GO', 'semantic': 'MolecularActivity'}],
#   'parameters': {'goid': '{inputs[0]}'},
#   'predicate': 'has_subclass',
#   'response_mapping': {'has_subclass': {'GO': 'results.children.id',
#     'name': 'results.children.name',
#     'relation': 'results.children.relation'}},
#   'source': 'gene ontology',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://www.ebi.ac.uk/QuickGO/services',
#    'params': {'goid': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/ontology/go/terms/{goid}/children',
#    'path_params': ['goid'],
#    'method': 'get',
#    'tags': ['ontology', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'GO',
#    'input_type': 'MolecularActivity',
#    'output_id': 'GO',
#    'output_type': 'MolecularActivity',
#    'predicate': 'has_subclass',
#    'source': 'gene ontology',
#    'api_name': 'QuickGO API',
#    'smartapi': {'id': '1f277e1563fcfd124bfae2cc3c4bcdec',
#     'meta': {'ETag': '756c2a5dad01f51c4c7a417696c98cb536a9f8eb3320336820a70a2d36e50b84',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:28.137864',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:30:17.100461',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/quickgo/smartapi.yaml'}}},
#   'id': 'a246820368387d99bb3e96472a78e14b0db37dde6354cd0eb10ca979'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'disgenet.genes_related_to_disease.gene_id'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'NCBIGene': 'disgenet.genes_related_to_disease.gene_id'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.genes_related_to_disease.gene_id'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '8c06fa45a09b121ffcc665e474b62edad9e521d07ae59f89669d165e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'DBSNP', 'semantic': 'SequenceVariant'}],
#   'parameters': {'fields': 'disgenet.variants_related_to_disease'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'DBSNP': 'disgenet.variants_related_to_disease.rsid',
#     'pubmed': 'disgenet.variants_related_to_disease.pubmed'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.variants_related_to_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'DBSNP',
#    'output_type': 'SequenceVariant',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': 'fa5c0c7e8962862091767ec4e053b343d385fa05455b570b075b33e2'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'OMIM', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'parameters': {'fields': 'hpo.phenotype_related_to_disease'},
#   'predicate': 'has_phenotype',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'hpo.omim'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'has_phenotype': {'HP': 'hpo.phenotype_related_to_disease.hpo_id',
#     'evidence': 'hpo.phenotype_related_to_disease.evidence',
#     'frequency': 'hpo.phenotype_related_to_disease.frequency'}},
#   'source': 'hpoa',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'hpo.phenotype_related_to_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'hpo.omim'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'OMIM',
#    'input_type': 'Disease',
#    'output_id': 'HP',
#    'output_type': 'PhenotypicFeature',
#    'predicate': 'has_phenotype',
#    'source': 'hpoa',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '40503f5675da711cf6f5a253d85546bf6486b824975397bff26f6479'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'ORPHANET', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'parameters': {'fields': 'hpo.phenotype_related_to_disease'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'hpo.orphanet'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'HP': 'hpo.phenotype_related_to_disease.hpo_id',
#     'evidence': 'hpo.phenotype_related_to_disease.evidence',
#     'frequency': 'hpo.phenotype_related_to_disease.frequency'}},
#   'source': 'hpoa',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'hpo.phenotype_related_to_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'hpo.orphanet'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'ORPHANET',
#    'input_type': 'Disease',
#    'output_id': 'HP',
#    'output_type': 'PhenotypicFeature',
#    'predicate': 'related_to',
#    'source': 'hpoa',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '11c3fd82364726d85b32847afb71cafee01f9c2b1dfc5ce5a2c654e9'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MESH', 'semantic': 'Disease'}],
#   'method': 'post',
#   'outputs': [{'id': 'MESH', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'ctd.chemical_related_to_disease'},
#   'path': '/query',
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mondo.xrefs.mesh, disgenet.xrefs.mesh'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'MESH': 'ctd.chemical_related_to_disease.mesh_chemical_id',
#     'pubmed': 'ctd.chemical_related_to_disease.pubmed'}},
#   'source': 'ctd',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'ctd.chemical_related_to_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mondo.xrefs.mesh, disgenet.xrefs.mesh'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MESH',
#    'input_type': 'Disease',
#    'output_id': 'MESH',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'ctd',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': 'a612fb7870b305841814071542094b4673fca82c7a3a9cca338a32b1'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MESH', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'GO', 'semantic': 'BiologicalProcess'}],
#   'parameters': {'fields': 'ctd.bp_related_to_disease'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mondo.xrefs.mesh, disgenet.xrefs.mesh'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'GO': 'ctd.bp_related_to_disease.go_id',
#     'name': 'ctd.bp_related_to_disease.go_name'}},
#   'source': 'ctd',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'ctd.bp_related_to_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mondo.xrefs.mesh, disgenet.xrefs.mesh'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MESH',
#    'input_type': 'Disease',
#    'output_id': 'GO',
#    'output_type': 'BiologicalProcess',
#    'predicate': 'related_to',
#    'source': 'ctd',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '92390d971d292c01ef1312f8f5749c3416fd938f772b188abfe6b3d1'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'disgenet.genes_related_to_disease.gene_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'UMLS': 'disgenet.xrefs.umls'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'disgenet.genes_related_to_disease.gene_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '747bd2f88e47e23f858fcc3ab8546d297d4e754d675b81ea29a2cb8e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'DBSNP', 'semantic': 'SequenceVariant'}],
#   'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'disgenet.variants_related_to_disease.rsid'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'UMLS': 'disgenet.xrefs.umls'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'disgenet.variants_related_to_disease.rsid'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DBSNP',
#    'input_type': 'SequenceVariant',
#    'output_id': 'UMLS',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '73dfe6d4cadbc364077f3463b391057ff9514e7bdb86fe28287e8d51'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'method': 'post',
#   'outputs': [{'id': 'OMIM', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'mondo.xrefs.omim', 'size': '250'},
#   'path': '/query',
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'hpo.phenotype_related_to_disease.hpo_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'OMIM': 'mondo.xrefs.omim'}},
#   'source': 'hpoa',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'mondo.xrefs.omim', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'hpo.phenotype_related_to_disease.hpo_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'HP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'OMIM',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'hpoa',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '8ec05d89cd013e8469f6887777539186365b380ab20580552d3c7b73'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MESH', 'semantic': 'ChemicalSubstance'}],
#   'method': 'post',
#   'outputs': [{'id': 'MESH', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'disgenet.xrefs.mesh', 'size': '250'},
#   'path': '/query',
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'ctd.chemical_related_to_disease.mesh_chemical_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'MESH': 'disgenet.xrefs.mesh'}},
#   'source': 'hpo',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.xrefs.mesh', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'ctd.chemical_related_to_disease.mesh_chemical_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MESH',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'MESH',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'hpo',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': 'e5cf20a00d8a6e571fd744e538f194d809d7a96713c8cbabcce107d1'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'GO', 'semantic': 'BiologicalProcess'}],
#   'method': 'post',
#   'outputs': [{'id': 'MESH', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'ctd.mesh', 'size': '250'},
#   'path': '/query',
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'ctd.bp_related_to_disease.go_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'MESH': 'ctd.mesh'}},
#   'source': 'ctd',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'ctd.mesh', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'ctd.bp_related_to_disease.go_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'GO',
#    'input_type': 'BiologicalProcess',
#    'output_id': 'MESH',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'ctd',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': 'caab24f47da456dbac0c597da7b61f73e78bad59da561cf0ecfa92f9'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'method': 'post',
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'mondo.descendants'},
#   'path': '/query',
#   'predicate': 'has_subclass',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'mondo.mondo'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'has_subclass': {'MONDO': 'mondo.descendants'}},
#   'source': 'mondo',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'mondo.descendants'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'mondo.mondo'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'has_subclass',
#    'source': 'mondo',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': 'b667babe6bbb7f12eed573f8f238d843859f689aa4541bf3882c18dc'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'method': 'post',
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'mondo.parents'},
#   'path': '/query',
#   'predicate': 'subclass_of',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'mondo.mondo'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'subclass_of': {'MONDO': 'mondo.parents'}},
#   'source': 'mondo',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'mondo.parents'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'mondo.mondo'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'subclass_of',
#    'source': 'mondo',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '6fbb3e60a63f3bc57fda662ba11fc22371983a3f24bd9e0f3cae55e032f3726c',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:01:52.845255',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:32.948297',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '791ec99d68665e725612a81353f38667b852c294352b7fbbf259d0bb'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': 'f4bfe8bb974bf412c817068a54c7c0a13ea7100fe3e18aaadc9de5db'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/chemical_substance/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': '74b58be1da7e04a9beea9d6a11ad4ebdfa0c9e8cce8acb234d1f0e12'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DOID', 'semantic': 'Disease'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'DOID': 'associated_with.doid'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/disease/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'DOID',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': '3bf464f7d85f6d009396fed24f6d0f1b6179514778ddcddda698a6ee'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'geneid': 'NCBIGene:{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'MONDO': 'associated_with.mondo'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'geneid': 'NCBIGene:{inputs[0]}'},
#    'request_body': None,
#    'path': '/gene/disease/{geneid}',
#    'path_params': ['geneid'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': 'f8320ddc452762306c8b363f1991762d131671b3627b791e1855afb8'},
#  {'inputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'DOID', 'semantic': 'Disease'}],
#   'parameters': {'chebi': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'DOID': 'associated_with.doid'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'chebi': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/chemical_substance/disease/{chebi}',
#    'path_params': ['chebi'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'CHEBI',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'DOID',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': 'b9690c9c474acdfa3739f564c4c34147759b0fd04a5f130e23ee4ec4'},
#  {'inputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'chebi': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'MONDO': 'associated_with.mondo'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'chebi': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/chemical_substance/disease/{chebi}',
#    'path_params': ['chebi'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'CHEBI',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': 'ec7ea01009f5b9742d5bf58f9696bc966fb3eb505e3484d44bd93d94'},
#  {'inputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'chebi': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBIGene': 'associated_with.ncbigene'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'chebi': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/chemical_substance/gene/{chebi}',
#    'path_params': ['chebi'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'CHEBI',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': '70c91ebbdeb49a14629fdb659a51215c7efe9aef1cd31dcc2b53d998'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'mondo': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBIGene': 'associated_with.ncbigene'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'mondo': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/disease/gene/{mondo}',
#    'path_params': ['mondo'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': '53e9c28f28b3b747a55b3ff280b248c4def5215047d60239c37847fe'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'mondo': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEMBL.COMPOUND': 'associated_with.chembl'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'mondo': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/disease/chemical_substance/{mondo}',
#    'path_params': ['mondo'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'CHEMBL.COMPOUND',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': 'f90d1c0610b5f7af9fa679c0e39fed74e85f76f333ab1d69adc8d080'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'CHEBI', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'mondo': '{inputs[0]}'},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'CHEBI': 'associated_with.chebi'}},
#   'source': 'scigraph',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://automat.renci.org/cord19-scigraph',
#    'params': {'mondo': '{inputs[0]}'},
#    'request_body': None,
#    'path': '/disease/chemical_substance/{mondo}',
#    'path_params': ['mondo'],
#    'method': 'get',
#    'tags': ['drug', 'gene', 'disease', 'automat', 'translator'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'CHEBI',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'related_to',
#    'source': 'scigraph',
#    'api_name': 'Automat CORD19 Scigraph API',
#    'smartapi': {'id': '8d5ef70318e800e7020eba5ca812a1b0',
#     'meta': {'ETag': '6a18f3c7e22f79c613df08c74a93cd93ea82372a146df65496ec8aabe30c39bd',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:19.572626',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:48.755410',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/scigraph/smartapi.yaml'}}},
#   'id': '710d2bf5bb9662fed5ce68fd8ee0125bf2397c198624599b9fae886c'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MGI', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'MP', 'semantic': 'PhenotypicFeature'}],
#   'parameters': {'fields': 'mgi.associated_with_phenotype'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': '_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'MP': 'mgi.associated_with_phenotype.mp',
#     'pubmed': 'mgi.associated_with_phenotype.pubmed'}},
#   'source': 'mgi_gene2phenotype',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/mgigene2phenotype',
#    'params': {'fields': 'mgi.associated_with_phenotype'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': '_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene',
#     'phenotype',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MGI',
#    'input_type': 'Gene',
#    'output_id': 'MP',
#    'output_type': 'PhenotypicFeature',
#    'predicate': 'related_to',
#    'source': 'mgi_gene2phenotype',
#    'api_name': 'MGIgene2phenotype API',
#    'smartapi': {'id': '77ed27f111262d0289ed4f4071faa619',
#     'meta': {'ETag': '3882689e9b0ab851d0610e71be4018068bff643772bc8611c0c77c0153c98151',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:24.514205',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:33.267916',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/MGIgene2phenotype/smartapi.yaml'}}},
#   'id': 'b23844a74c1f3966352af8b903dff6be6a8da344c2d1ebce2c5ab5c8'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MGI', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DOID', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'mgi.associated_with_disease'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': '_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'DOID': 'mgi.associated_with_disease.doid',
#     'name': 'mgi.associated_with_disease.name'}},
#   'source': 'mgi_gene2phenotype',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/mgigene2phenotype',
#    'params': {'fields': 'mgi.associated_with_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': '_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene',
#     'phenotype',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MGI',
#    'input_type': 'Gene',
#    'output_id': 'DOID',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'mgi_gene2phenotype',
#    'api_name': 'MGIgene2phenotype API',
#    'smartapi': {'id': '77ed27f111262d0289ed4f4071faa619',
#     'meta': {'ETag': '3882689e9b0ab851d0610e71be4018068bff643772bc8611c0c77c0153c98151',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:24.514205',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:33.267916',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/MGIgene2phenotype/smartapi.yaml'}}},
#   'id': 'e4bf019020279c8d5efbf43f6b4d5dcb5bd70a29d8831b8ba91f110b'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'MP', 'semantic': 'PhenotypicFeature'}],
#   'outputs': [{'id': 'MGI', 'semantic': 'Gene'}],
#   'parameters': {'fields': '_id', 'size': '300'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mgi.associated_with_phenotype.mp'}},
#   'response_mapping': {'related_to': {'MGI': '_id'}},
#   'source': 'mgi_gene2phenotype',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/mgigene2phenotype',
#    'params': {'fields': '_id', 'size': '300'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mgi.associated_with_phenotype.mp'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene',
#     'phenotype',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'MP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'MGI',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': 'mgi_gene2phenotype',
#    'api_name': 'MGIgene2phenotype API',
#    'smartapi': {'id': '77ed27f111262d0289ed4f4071faa619',
#     'meta': {'ETag': '3882689e9b0ab851d0610e71be4018068bff643772bc8611c0c77c0153c98151',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:24.514205',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:33.267916',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/MGIgene2phenotype/smartapi.yaml'}}},
#   'id': '3952de7388888d49dc973793f72dd04926699056c1c847a0e047e689'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'DOID', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'MGI', 'semantic': 'Gene'}],
#   'parameters': {'fields': '_id', 'size': '300'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mgi.associated_with_disease.doid'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'MGI': '_id'}},
#   'source': 'mgi_gene2phenotype',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/mgigene2phenotype',
#    'params': {'fields': '_id', 'size': '300'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mgi.associated_with_disease.doid'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene',
#     'phenotype',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DOID',
#    'input_type': 'Disease',
#    'output_id': 'MGI',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': 'mgi_gene2phenotype',
#    'api_name': 'MGIgene2phenotype API',
#    'smartapi': {'id': '77ed27f111262d0289ed4f4071faa619',
#     'meta': {'ETag': '3882689e9b0ab851d0610e71be4018068bff643772bc8611c0c77c0153c98151',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:05:24.514205',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:33.267916',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/MGIgene2phenotype/smartapi.yaml'}}},
#   'id': 'a18bb2ecc09e48f16d74a8c6c2f11adc1e6917f3cdcae0bdef3d9367'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'AnatomicalEntity'}],
#   'parameters': {'fields': 'affected_by'},
#   'path': '/query',
#   'predicate': 'affected_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'affected_by': {'pmid': 'affected_by.pmid',
#     'umls': 'affected_by.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmed',
#    'params': {'fields': 'affected_by'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'UMLS',
#    'output_type': 'AnatomicalEntity',
#    'predicate': 'affected_by',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Disease API',
#    'smartapi': {'id': 'ed0ee52921c7cbce24033ffd1369922e',
#     'meta': {'ETag': '5ac350c8d80b8ec232986a10e3a57f8e4ed40f84e29227a625149b464b0b334d',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:03:08.522992',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:31.068849',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_disease.yaml'}}},
#   'id': 'e330ac38c86a069ce4bc8fd7720dae4f65a700e5316ec8d0be6135bc'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'method': 'post',
#   'outputs': [{'id': 'UMLS', 'semantic': 'Cell'}],
#   'parameters': {'fields': 'affected_by'},
#   'path': '/query',
#   'predicate': 'affected_by',
#   'requestBody': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#   'response_mapping': {'affected_by': {'pmid': 'affected_by.pmid',
#     'umls': 'affected_by.umls'}},
#   'source': 'SEMMED',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/semmed',
#    'params': {'fields': 'affected_by'},
#    'request_body': {'body': {'q': '{inputs[0]}', 'scopes': 'umls'}},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'semmed'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'UMLS',
#    'output_type': 'Cell',
#    'predicate': 'affected_by',
#    'source': 'SEMMED',
#    'api_name': 'SEMMED Disease API',
#    'smartapi': {'id': 'ed0ee52921c7cbce24033ffd1369922e',
#     'meta': {'ETag': '5ac350c8d80b8ec232986a10e3a57f8e4ed40f84e29227a625149b464b0b334d',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-12-07T23:03:08.522992',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:31.068849',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmed/semmed_disease.yaml'}}},
# ...
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': '48dfa517b786a0f94a0b93e1df39f40dc684dc1b64e37c5cc6effbf0'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'PR', 'semantic': 'Protein'}],
#   'parameters': {'fields': 'object,association',
#    'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:Protein',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'PR': 'hits.object.PR',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'object,association',
#     'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:Protein',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'PR',
#    'output_type': 'Protein',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': '3457bbdca8f2193a9056df2ed2bbb3970f1f6e6f9e9fbf4cdae8f8d4'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'PR', 'semantic': 'Protein'}],
#   'parameters': {'fields': 'subject,association',
#    'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:Protein',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'PR': 'hits.subject.PR',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'subject,association',
#     'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:Protein',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'PR',
#    'output_type': 'Protein',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': 'cf44c187393ae123cc35bb36b4f7ac084c0500b249b5229824448cd1'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'SO', 'semantic': 'SequenceFeature'}],
#   'parameters': {'fields': 'object,association',
#    'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:SequenceFeature',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'SO': 'hits.object.SO',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'object,association',
#     'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:SequenceFeature',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'SO',
#    'output_type': 'SequenceFeature',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': 'a2f343def88ee901b53468aa5402ab72bc72056ccdaf22a6c1e3f433'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'SO', 'semantic': 'SequenceFeature'}],
#   'parameters': {'fields': 'subject,association',
#    'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:SequenceFeature',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'SO': 'hits.subject.SO',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'subject,association',
#     'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:SequenceFeature',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'SO',
#    'output_type': 'SequenceFeature',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': '585cd89c37eb15bf33c1f8d032a6746ebfb6d40cc5a0366a7132f8db'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'UBERON', 'semantic': 'AnatomicalEntity'}],
#   'parameters': {'fields': 'object,association',
#    'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:AnatomicalEntity',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'UBERON': 'hits.object.UBERON',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'object,association',
#     'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:AnatomicalEntity',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'UBERON',
#    'output_type': 'AnatomicalEntity',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': 'b6cd96deac26017c286ab25bf1be238cc59de38ba8e3d0226382f846'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'UBERON', 'semantic': 'AnatomicalEntity'}],
#   'parameters': {'fields': 'subject,association',
#    'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:AnatomicalEntity',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'UBERON': 'hits.subject.UBERON',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'subject,association',
#     'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:AnatomicalEntity',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'UBERON',
#    'output_type': 'AnatomicalEntity',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': '1944f8a068dfac21e682d2b0c33714d6c8fd1d6efe7decd3170e7f96'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'parameters': {'fields': 'object,association',
#    'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:OrganismTaxon',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBITaxon': 'hits.object.NCBITaxon',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'object,association',
#     'q': 'subject.NCBITaxon:"{inputs[0]}" AND object.type:OrganismTaxon',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'NCBITaxon',
#    'output_type': 'OrganismTaxon',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': '7db4fe913cb2b9c0fa5f70a6a1b17b0cd992e14a80f57c05b59fc478'},
#  {'inputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'outputs': [{'id': 'NCBITaxon', 'semantic': 'OrganismTaxon'}],
#   'parameters': {'fields': 'subject,association',
#    'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:OrganismTaxon',
#    'size': 1000},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBITaxon': 'hits.subject.NCBITaxon',
#     'ngd': 'hits.association.ngd'}},
#   'source': 'Text Mining KP',
#   'supportBatch': False,
#   'query_operation': {'server': 'https://biothings.ncats.io/text_mining_co_occurrence_kp',
#    'params': {'fields': 'subject,association',
#     'q': 'object.NCBITaxon:"{inputs[0]}" AND subject.type:OrganismTaxon',
#     'size': 1000},
#    'request_body': None,
#    'path': '/query',
#    'path_params': [],
#    'method': 'get',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBITaxon',
#    'input_type': 'OrganismTaxon',
#    'output_id': 'NCBITaxon',
#    'output_type': 'OrganismTaxon',
#    'predicate': 'related_to',
#    'source': 'Text Mining KP',
#    'api_name': 'Text Mining CO-OCCURRENCE API',
#    'smartapi': {'id': '5be0f321a829792e934545998b9c6afe',
#     'meta': {'ETag': 'ea1de319807d37d62c13b7e98a86b339b82f3952d85f4966b2699d6a1945252f',
#      'github_username': 'kevinxin90',
#      'timestamp': '2021-01-12T23:30:46.860511',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:28:13.579672',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/text_mining/cooccurrence.yaml'}}},
#   'id': 'cf1c2f9306a2122dce8c1b6a6ac3cdef3a33f8eccce7afd0fc7e523d'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'CHEMBL.COMPOUND', 'semantic': 'ChemicalSubstance'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'subject.NCBIGene,association.provided_by,association.pubmed',
#    'size': 1000},
#   'predicate': 'physically_interacts_with',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'object.CHEMBL_COMPOUND'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'physically_interacts_with': {'NCBIGene': 'subject.NCBIGene',
#     'pubmed': 'association.pubmed',
#     'source': 'association.provided_by'}},
#   'source': 'DGIdb',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://biothings.ncats.io/dgidb',
#    'params': {'fields': 'subject.NCBIGene,association.provided_by,association.pubmed',
#     'size': 1000},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'object.CHEMBL_COMPOUND'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['gene',
#     'chemical',
#     'association',
#     'annotation',
#     'query',
#     'translator',
#     'biothings',
#     'biothings_graph'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'CHEMBL.COMPOUND',
#    'input_type': 'ChemicalSubstance',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'physically_interacts_with',
#    'source': 'DGIdb',
#    'api_name': 'BioThings DGIdb API',
#    'smartapi': {'id': 'e3edd325c76f2992a111b43a907a4870',
#     'meta': {'ETag': '832ad7b7c0e20144712db5430227e191ea53c35820ba2b5a3732add8b337d97a',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-09T00:02:20.664785',
#      'uptime_status': 'good',
#      'uptime_ts': '2021-01-20T00:29:45.404059',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/dgidb/openapi.yml'}}},
#   'id': '14507cd12eb986d9b5707f9cd566be1a4c6613ec15ac949c1a723732'},
#  ...]

# %% [markdown]
# # Filter

# %% [markdown]
# ## Filter for Meta-KG operations with Gene as Input and ChemicalSubstance as output

# %%
dfjskl = kg.filter({})

# %%
[i.get('inputSeparator') for i in dfjskl]
# Out:
# [None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  None,
#  None,
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',',
#  ',']

# %% [markdown]
# ## Find Meta-KG operations that converys Gene->Metabolize->ChemicalSubstance

# %%
kg.filter({"input_type": "Gene", "output_type": "ChemicalSubstance", "predicate": "metabolize"})
# Out:
# [{'inputSeparator': ',',
#   'inputs': [{'id': 'SYMBOL', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'DRUGBANK', 'semantic': 'ChemicalSubstance'}],
#   'parameters': {'fields': 'drugbank.id', 'size': '250'},
#   'predicate': 'metabolize',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'drugbank.enzymes.gene_name'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'metabolize': {'DRUGBANK': 'drugbank.id'}},
#   'source': 'drugbank',
#   'supportBatch': True,
#   'query_operation': {'server': 'https://mychem.info/v1',
#    'params': {'fields': 'drugbank.id', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'drugbank.enzymes.gene_name'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['chemical',
#     'drug',
#     'annotation',
#     'query',
#     'translator',
#     'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'SYMBOL',
#    'input_type': 'Gene',
#    'output_id': 'DRUGBANK',
#    'output_type': 'ChemicalSubstance',
#    'predicate': 'metabolize',
#    'source': 'drugbank',
#    'api_name': 'MyChem.info API',
#    'smartapi': {'id': '8f08d1446e0bb9c2b323713ce83e2bd3',
#     'meta': {'ETag': '29b19766c916462007652823e9c542fb0592b2919f22de80edbb52354b0cc1b3',
#      'github_username': 'newgene',
#      'slug': 'mychem',
#      'timestamp': '2020-12-08T00:00:41.831538',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-12-11T00:09:17.761407',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mychem.info/openapi_full.yml'}}},
#   'id': 'a67b7d970c49ef7f495375dab9af17995a0283416b2e5506df98e8ab'}]

# %% [markdown]
# ## Filter for Knowledge Graph Operations supported by MyChem.info as API source

# %%
kg.filter({"api_name": "BioLink API"})
# Out:
# [{'inputs': [{'id': 'UBERON', 'semantic': 'AnatomicalEntity'}],
#   'outputs': [{'id': 'HGNC', 'semantic': 'Gene'}],
#   'parameters': {'anatomy_id': '{inputs[0]}',
#    'direct': True,
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'HGNC': 'associations.object.HGNC',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'anatomy_id': '{inputs[0]}',
#     'direct': True,
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/anatomy/{anatomy_id}/genes',
#    'path_params': ['anatomy_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'UBERON',
#    'input_type': 'AnatomicalEntity',
#    'output_id': 'HGNC',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '38bef1b396798e55f207a0a699dfab9592e0c655767c013361aaad95'},
#  {'inputs': [{'id': 'UBERON', 'semantic': 'AnatomicalEntity'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'anatomy_id': '{inputs[0]}',
#    'direct': True,
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBIGene': 'associations.object.NCBIGene',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'anatomy_id': '{inputs[0]}',
#     'direct': True,
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/anatomy/{anatomy_id}/genes',
#    'path_params': ['anatomy_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'UBERON',
#    'input_type': 'AnatomicalEntity',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '6d28df1c2a3419cac370452c3eca44cae9fff391d4bcdea43eddd82c'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'HGNC', 'semantic': 'Gene'}],
#   'parameters': {'direct': True,
#    'disease_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'HGNC': 'associations.object.HGNC',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by',
#     'taxid': 'associations.object.taxon.id'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'disease_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/disease/{disease_id}/genes',
#    'path_params': ['disease_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'HGNC',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'd872f2bb667aa72d16d3534f9c45232714f0103f6be187c9d0dd3084'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'direct': True,
#    'disease_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBIGene': 'associations.object.NCBIGene',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by',
#     'taxid': 'associations.object.taxon.id'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'disease_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/disease/{disease_id}/genes',
#    'path_params': ['disease_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'c0200476236436619412240f0fcc95b682b3b627d1b1bb63ee6f0be6'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'REACT', 'semantic': 'Pathway'}],
#   'parameters': {'direct': True,
#    'disease_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'REACT': 'associations.object.REACT',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'disease_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/disease/{disease_id}/pathways',
#    'path_params': ['disease_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'REACT',
#    'output_type': 'Pathway',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '88b1d71256c70e24e51f2a9db22894496b8f54125e3af364d7e07ad3'},
#  {'inputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'parameters': {'direct': True,
#    'disease_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'has_phenotype',
#   'response_mapping': {'has_phenotype': {'HP': 'associations.object.HP',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'disease_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/disease/{disease_id}/phenotypes',
#    'path_params': ['disease_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'MONDO',
#    'input_type': 'Disease',
#    'output_id': 'HP',
#    'output_type': 'PhenotypicFeature',
#    'predicate': 'has_phenotype',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'edfd253c3b5e21460429408ba397baaeb97f5be9dc7d8c7e1fb452a6'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'UBERON', 'semantic': 'AnatomicalEntity'}],
#   'parameters': {'direct': True,
#    'gene_id': 'NCBIGene:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'UBERON': 'associations.object.UBERON',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'gene_id': 'NCBIGene:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/gene/{gene_id}/anatomy',
#    'path_params': ['gene_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'UBERON',
#    'output_type': 'AnatomicalEntity',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'f4a14c9cb02b34834fff643918698e1ab72b2a0aabfc58571bbf92a8'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'direct': True,
#    'gene_id': 'NCBIGene:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'MONDO': 'associations.object.MONDO',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'gene_id': 'NCBIGene:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/gene/{gene_id}/diseases',
#    'path_params': ['gene_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '34df9732907101cc199e88f6ae55fc111cdcca5744a3fb160a7c5f97'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'HGNC', 'semantic': 'Gene'}],
#   'parameters': {'direct': True,
#    'gene_id': 'NCBIGene:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'physically_interacts_with',
#   'response_mapping': {'physically_interacts_with': {'HGNC': 'associations.object.HGNC',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by',
#     'taxid': 'associations.object.taxon.id'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'gene_id': 'NCBIGene:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/gene/{gene_id}/interactions',
#    'path_params': ['gene_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'HGNC',
#    'output_type': 'Gene',
#    'predicate': 'physically_interacts_with',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'b70a23271d0446e3e91955138c2027b3a573ccd7bfd2f2943a1b5454'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'HGNC', 'semantic': 'Gene'}],
#   'parameters': {'direct': True,
#    'gene_id': 'NCBIGene:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBIGene': 'associations.object.NCBIGene',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by',
#     'taxid': 'associations.object.taxon.id'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'gene_id': 'NCBIGene:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/gene/{gene_id}/interactions',
#    'path_params': ['gene_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'HGNC',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'b70a23271d0446e3e91955138c2027b3a573ccd7bfd2f2943a1b5454'},
#  {'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'parameters': {'direct': True,
#    'gene_id': 'NCBIGene:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'HP': 'associations.object.HP',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'gene_id': 'NCBIGene:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/gene/{gene_id}/phenotypes',
#    'path_params': ['gene_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'HP',
#    'output_type': 'PhenotypicFeature',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '8129b5e54ac258dbe44ce1dbb3eb342b844dbd40afdfe9a3683d7ef7'},
#  {'inputs': [{'id': 'REACT', 'semantic': 'Pathway'}],
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'direct': True,
#    'pathway_id': 'REACT:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'MONDO': 'associations.object.MONDO',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'pathway_id': 'REACT:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/pathway/{pathway_id}/diseases',
#    'path_params': ['pathway_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'REACT',
#    'input_type': 'Pathway',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '639b94660fa803afc31ccdd3b9f229f77c995aaee416f9128f60fd6c'},
#  {'inputs': [{'id': 'REACT', 'semantic': 'Pathway'}],
#   'outputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'parameters': {'direct': True,
#    'gene_id': 'REACT:{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'HP': 'associations.object.HP',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'gene_id': 'REACT:{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/pathway/{pathway_id}/phenotypes',
#    'path_params': ['pathway_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'REACT',
#    'input_type': 'Pathway',
#    'output_id': 'HP',
#    'output_type': 'PhenotypicFeature',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '60ae7bfb08cd6b4078d9c5b1050d606e196d63ef4160cf0c340d6120'},
#  {'inputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'outputs': [{'id': 'HGNC', 'semantic': 'Gene'}],
#   'parameters': {'direct': True,
#    'phenotype_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'HGNC': 'associations.object.HGNC',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'phenotype_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/phenotype/{phenotype_id}/genes',
#    'path_params': ['phenotype_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'HP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'HGNC',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '4084032458562f7f1bc95017ddfd89b5ce10b63ad83ea054ee6ca97b'},
#  {'inputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'direct': True,
#    'phenotype_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'NCBIGene': 'associations.object.NCBIGene',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'phenotype_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/phenotype/{phenotype_id}/genes',
#    'path_params': ['phenotype_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'HP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': 'fb383631f954b6f233510f589ff390abd4c908f5a598d7d58f2d40d5'},
#  {'inputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'outputs': [{'id': 'REACT', 'semantic': 'Pathway'}],
#   'parameters': {'direct': True,
#    'phenotype_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'REACT': 'associations.object.REACT',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'phenotype_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/phenotype/{phenotype_id}/pathways',
#    'path_params': ['phenotype_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'HP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'REACT',
#    'output_type': 'Pathway',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '0455e1df6d75da6c4e2a2c02b6ec654a1a969b1f9f3497cbee4e9212'},
#  {'inputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'outputs': [{'id': 'DBSNP', 'semantic': 'SequenceVariant'}],
#   'parameters': {'direct': True,
#    'phenotype_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'DBSNP': 'associations.object.DBSNP',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'phenotype_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/phenotype/{phenotype_id}/variants',
#    'path_params': ['phenotype_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'HP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'DBSNP',
#    'output_type': 'SequenceVariant',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '889a52731c5669f36664e7a0b65375fddab8238d719c6c491c276504'},
#  {'inputs': [{'id': 'HP', 'semantic': 'PhenotypicFeature'}],
#   'outputs': [{'id': 'MONDO', 'semantic': 'Disease'}],
#   'parameters': {'direct': True,
#    'phenotype_id': '{inputs[0]}',
#    'rows': 200,
#    'unselect_evidence': True},
#   'predicate': 'related_to',
#   'response_mapping': {'related_to': {'MONDO': 'associations.object.MONDO',
#     'name': 'associations.object.label',
#     'pubmed': 'associations.publications.id',
#     'relation': 'associations.relation.label',
#     'source': 'associations.provided_by'}},
#   'supportBatch': False,
#   'query_operation': {'server': 'https://api.monarchinitiative.org/api',
#    'params': {'direct': True,
#     'phenotype_id': '{inputs[0]}',
#     'rows': 200,
#     'unselect_evidence': True},
#    'request_body': None,
#    'path': '/bioentity/phenotype/{phenotype_id}/diseases',
#    'path_params': ['phenotype_id'],
#    'method': 'get',
#    'tags': ['anatomy',
#     'disease',
#     'gene',
#     'phenotype',
#     'pathway',
#     'annotation',
#     'query',
#     'translator',
#     'biolink'],
#    'supportBatch': False,
#    'inputSeparator': None},
#   'association': {'input_id': 'HP',
#    'input_type': 'PhenotypicFeature',
#    'output_id': 'MONDO',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': None,
#    'api_name': 'BioLink API',
#    'smartapi': {'id': 'd22b657426375a5295e7da8a303b9893',
#     'meta': {'ETag': '5e312d0aa9bca165e68f0ed2241a89fa058156e6c81e4133ca5e82378d2584a0',
#      'github_username': 'newgene',
#      'timestamp': '2020-09-11T00:02:44.238024',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-18T00:09:04.189285',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biolink/openapi.yml'}}},
#   'id': '280f95f7d784287901db1508cbca0105300cee36ee85fdfcfa532df4'}]

# %% [markdown]
# ## Filter for API operations with drugbank as data source

# %%
kg.filter({"source": "disgenet"})
# Out:
# [{'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'parameters': {'fields': 'disgenet.genes_related_to_disease.gene_id'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'NCBIGene': 'disgenet.genes_related_to_disease.gene_id'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.genes_related_to_disease.gene_id'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'NCBIGene',
#    'output_type': 'Gene',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '19a461466ee1ae1dbb8aca6a8af8036efe574ea8d3e5eb470e6ef3a585aeed67',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-10-16T17:22:39.512638',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-09T00:08:59.435477',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '8c06fa45a09b121ffcc665e474b62edad9e521d07ae59f89669d165e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'outputs': [{'id': 'DBSNP', 'semantic': 'SequenceVariant'}],
#   'parameters': {'fields': 'disgenet.variants_related_to_disease'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'DBSNP': 'disgenet.variants_related_to_disease.rsid',
#     'pubmed': 'disgenet.variants_related_to_disease.pubmed'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.variants_related_to_disease'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'mondo.xrefs.umls, disgenet.xrefs.umls'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'UMLS',
#    'input_type': 'Disease',
#    'output_id': 'DBSNP',
#    'output_type': 'SequenceVariant',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '19a461466ee1ae1dbb8aca6a8af8036efe574ea8d3e5eb470e6ef3a585aeed67',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-10-16T17:22:39.512638',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-09T00:08:59.435477',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': 'fa5c0c7e8962862091767ec4e053b343d385fa05455b570b075b33e2'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'NCBIGene', 'semantic': 'Gene'}],
#   'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'disgenet.genes_related_to_disease.gene_id'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'UMLS': 'disgenet.xrefs.umls'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'disgenet.genes_related_to_disease.gene_id'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'NCBIGene',
#    'input_type': 'Gene',
#    'output_id': 'UMLS',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '19a461466ee1ae1dbb8aca6a8af8036efe574ea8d3e5eb470e6ef3a585aeed67',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-10-16T17:22:39.512638',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-09T00:08:59.435477',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '747bd2f88e47e23f858fcc3ab8546d297d4e754d675b81ea29a2cb8e'},
#  {'inputSeparator': ',',
#   'inputs': [{'id': 'DBSNP', 'semantic': 'SequenceVariant'}],
#   'outputs': [{'id': 'UMLS', 'semantic': 'Disease'}],
#   'parameters': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#   'predicate': 'related_to',
#   'requestBody': {'body': {'q': '{inputs[0]}',
#     'scopes': 'disgenet.variants_related_to_disease.rsid'},
#    'header': 'application/x-www-form-urlencoded'},
#   'response_mapping': {'related_to': {'UMLS': 'disgenet.xrefs.umls'}},
#   'source': 'disgenet',
#   'supportBatch': True,
#   'query_operation': {'server': 'http://mydisease.info/v1',
#    'params': {'fields': 'disgenet.xrefs.umls', 'size': '250'},
#    'request_body': {'body': {'q': '{inputs[0]}',
#      'scopes': 'disgenet.variants_related_to_disease.rsid'},
#     'header': 'application/x-www-form-urlencoded'},
#    'path': '/query',
#    'path_params': [],
#    'method': 'post',
#    'tags': ['disease', 'annotation', 'query', 'translator', 'biothings'],
#    'supportBatch': True,
#    'inputSeparator': ','},
#   'association': {'input_id': 'DBSNP',
#    'input_type': 'SequenceVariant',
#    'output_id': 'UMLS',
#    'output_type': 'Disease',
#    'predicate': 'related_to',
#    'source': 'disgenet',
#    'api_name': 'mydisease.info API',
#    'smartapi': {'id': '671b45c0301c8624abbd26ae78449ca2',
#     'meta': {'ETag': '19a461466ee1ae1dbb8aca6a8af8036efe574ea8d3e5eb470e6ef3a585aeed67',
#      'github_username': 'kevinxin90',
#      'timestamp': '2020-10-16T17:22:39.512638',
#      'uptime_status': 'good',
#      'uptime_ts': '2020-11-09T00:08:59.435477',
#      'url': 'https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mydisease.info/smartapi.yaml'}}},
#   'id': '73dfe6d4cadbc364077f3463b391057ff9514e7bdb86fe28287e8d51'}]
